# %% [markdown]
# # NOTEBOOK: EXPLORATORY
#
# # Exploratory Notebook
#
# The first half of this notebook showcases some of the exploratory procedures that (e.g. modifying and understanding particular aspects of the utilised libraries and codebases). As such, the first half is prior to hypothesis formation.
#
# The second half of this notebook aims to provide suplementary materials that help augment our discussions within the paper. For instance, as at least one of the stated hypotheses was proven false, we are motivated to try and understand why this may be the case. While we offer at least one (seemingly) obvious explaination within our discussion (i.e. the model is adequately capturing the syntactic language properties of the given data and the additional PoS/DepRel tags may simply be introducing noise; or prividing minimal benefit), we outline data issues which may be contributing to why the proposed methods may not be as performant as we had originally hoped.

# %%
from tqdm import tqdm
import ujson as json
import sys
import os

# %%
sys.path.insert(0, '../models/RE_improved_baseline');
from transformers import AutoConfig, AutoTokenizer
from prepro import TACREDProcessor, RETACREDProcessor, Processor
from prepro import convert_token

# %%
train_file = os.path.join("./train_examples.json");
dev_file = os.path.join("./dev_examples.json");
test_file = os.path.join("./test_examples.json");

# %%
with open(train_file, "r") as target_train_file:
    train_samples = json.load(target_train_file)

with open(train_file, "r") as target_dev_file:
    dev_samples = json.load(target_dev_file)

with open(test_file, "r") as target_test_file:
    test_samples = json.load(target_test_file)

# %%
# Note that this code is mainly drawn from the codebase at large.
# some effort was made to import the specific modules required, 
# then to override (method overriding) the tokenize method in order to minimise
# redundant code, but overriding methods in this way (in python) seemed to introduce
# breaking changes, as such, please just skim the code and take notice of any comments
#
# Thanks!

def convert_token(token):
    """ Convert PTB tokens to normal tokens """
    if (token.lower() == '-lrb-'):
        return '('
    elif (token.lower() == '-rrb-'):
        return ')'
    elif (token.lower() == '-lsb-'):
        return '['
    elif (token.lower() == '-rsb-'):
        return ']'
    elif (token.lower() == '-lcb-'):
        return '{'
    elif (token.lower() == '-rcb-'):
        return '}'
    return token


class Processor:
    def __init__(self, args, tokenizer):
        super().__init__()
        self.args = args
        self.tokenizer = tokenizer
        self.new_tokens = []
        if self.args.input_format == 'entity_marker':
            self.new_tokens = ['[E1]', '[/E1]', '[E2]', '[/E2]']
        self.tokenizer.add_tokens(self.new_tokens)
        # changes: added 'typed_entity_marker_pos', 'typed_entity_marker_pos_punct' to the list of valid formats
        if self.args.input_format not in ('entity_mask', 'entity_marker', 'entity_marker_punct', 'typed_entity_marker', 'typed_entity_marker_punct', 'typed_entity_marker_pos', 'typed_entity_marker_pos_seq', 'typed_entity_marker_pos_set', 'typed_entity_marker_pos_punct', 'typed_entity_marker_pos_seq_punct', 'typed_entity_marker_pos_set_punct'):
            raise Exception("Invalid input format!")

    def tokenize(self, tokens, subj_type, obj_type, ss, se, os, oe, pos_tags=None, deprel_tags=None):
        if not pos_tags:
            raise Exception("No pos tags supplied.");
        """
        Implement the following input formats:
            - entity_mask: [SUBJ-NER], [OBJ-NER].
            - entity_marker: [E1] subject [/E1], [E2] object [/E2].
            - entity_marker_punct: @ subject @, # object #.
            - typed_entity_marker: [SUBJ-NER] subject [/SUBJ-NER], [OBJ-NER] obj [/OBJ-NER]
            - typed_entity_marker_punct: @ * subject ner type * subject @, # ^ object ner type ^ object #
            - typed_entity_marker_pos: [SUBJ-NER*POS1] subject [/SUBJ-NER*POS1], [OBJ-NER*POS1] obj [/OBJ-NER*POS1] <-- Appends the first PoS tag to the marker
            - typed_entity_marker_pos_seq: [SUBJ-NER*POS1+POS2] subject [/SUBJ-NER*POS1+POS2], [OBJ-NER*POS1+POS2] obj [/OBJ-NER*POS1+POS2] <-- Appends all PoS tags \in multiset(entity_{POStags})
            - typed_entity_marker_pos_set: [SUBJ-NER*UNIQUEPOS1+UNIQUEPOS2] subject [/SUBJ-NER*UNIQUEPOS1+UNIQUEPOS2], [OBJ-NER*UNIQUEPOS1+UNIQUEPOS2] obj [/OBJ-NER*UNIQUEPOS1+UNIQUEPOS2] <-- Appends all PoS tags \in set(entity_{POStags})
            - typed_entity_marker_pos_punct: @ * subject ner type + pos tag * subject @, # ^ object ner type pos tag ^ object # <-- Appends first PoS tag using punct representation
            - typed_entity_marker_pos_seq_punct: @ * subject ner type + pos_1 + pos_2 * subject_{token_{1}} subject_{token_{2}} @, # ^ object ner type pos_1 ^ object # <-- Appends all PoS tags \in multiset(entity_{POStags}) using punct representation
            - typed_entity_marker_pos_set_punct: @ * subject ner type + pos_1 + pos_2 * subject_{token_{1}} subject_{token_{2}} @, # ^ object ner type pos_1 ^ object # <-- Appends all PoS tags \in multiset(entity_{POStags}) using punct representation
        """
        
        sents = []
        input_format = self.args.input_format
        
        if input_format == 'entity_mask':
            subj_type = '[SUBJ-{}]'.format(subj_type)
            obj_type = '[OBJ-{}]'.format(obj_type)
            for token in (subj_type, obj_type):
                if token not in self.new_tokens:
                    self.new_tokens.append(token)
                    self.tokenizer.add_tokens([token])
        
        elif input_format == 'typed_entity_marker':
            subj_start = '[SUBJ-{}]'.format(subj_type)
            subj_end = '[/SUBJ-{}]'.format(subj_type)
            obj_start = '[OBJ-{}]'.format(obj_type)
            obj_end = '[/OBJ-{}]'.format(obj_type)
            for token in (subj_start, subj_end, obj_start, obj_end):
                if token not in self.new_tokens:
                    self.new_tokens.append(token)
                    self.tokenizer.add_tokens([token])
        
        # approach #1: producing a subj/obj strart & subj/obj end tag by appending the PoS tag @ ss, se, os & oe \in multiset(entity_{POStags}) to 'subject/object' & entity-type:
        # e.g. [SUBJ-PERSON-NPP] Alice Dellal [/SUBJ-PERSON-NPP]
        elif input_format == 'typed_entity_marker_pos':
            # construct subject tags
            subj_start = '[SUBJ-{}*{}]'.format(subj_type, pos_tags[ss]);
            subj_end = '[/SUBJ-{}*{}]'.format(subj_type, pos_tags[se]);
            # & object tags
            obj_start = '[OBJ-{}*{}]'.format(obj_type, pos_tags[os]);
            obj_end = '[/OBJ-{}*{}]'.format(obj_type, pos_tags[oe]);
            # if these tokens are considered unseen new tokens, add them to the set of new tokens
            for token in (subj_start, subj_end, obj_start, obj_end):
                if token not in self.new_tokens:
                    self.new_tokens.append(token);
                    self.tokenizer.add_tokens([token]);
        
        # approach #2: producing a subj start & subj end tag by concat'ing the subject/object, entity-type & sequenced PoS tags together
        # if the entity length is > 1, then produce [SUBJ-TYPE*POS1+POS2] subj_token_1 subj_token_2 [/SUBJ-TYPE*POS1+POS2] & same for the obj
        elif input_format == 'typed_entity_marker_pos_seq':
            # grabbing the PoS between the subject start & subject end 
            subj_pos_tags = pos_tags[ss : se + 1];
            # constructing a PoS string to represent the sequence of tags
            subj_pos_string = "+".join(subj_pos_tags);
            # building the subj opening & closing tag
            subj_start = '[SUBJ-{}*{}]'.format(subj_type, subj_pos_string);
            subj_end = '[/SUBJ-{}*{}]'.format(subj_type, subj_pos_string);
            # same again for object start & end tag
            obj_pos_tags = pos_tags[os : oe + 1];
            obj_pos_string = "+".join(obj_pos_tags);
            obj_start = '[OBJ-{}*{}]'.format(obj_type, obj_pos_string);
            obj_end = '[/OBJ-{}*{}]'.format(obj_type, obj_pos_string);
            # if these tokens are considered unseen new tokens, add them to the set of new tokens
            for token in (subj_start, subj_end, obj_start, obj_end):
                if token not in self.new_tokens:
                    self.new_tokens.append(token);
                    self.tokenizer.add_tokens([token]);

        # approach #3: similar to approach #2, but simply take the set of PoS tags
        elif input_format == 'typed_entity_marker_pos_set':
            # rather than use set(), we're going to retain some degree of order
            subj_pos_tags = list(dict.fromkeys(pos_tags[ss : se + 1]));
            subj_pos_string = "+".join(subj_pos_tags);
            subj_start = '[SUBJ-{}*{}]'.format(subj_type, subj_pos_string);
            subj_end = '[/SUBJ-{}*{}]'.format(subj_type, subj_pos_string);
            # same for obj
            obj_pos_tags = list(dict.fromkeys(pos_tags[os : oe + 1]));
            obj_pos_string = "+".join(obj_pos_tags);
            obj_start = '[OBJ-{}*{}]'.format(obj_type, obj_pos_string);
            obj_end = '[/OBJ-{}*{}]'.format(obj_type, obj_pos_string);
            for token in (subj_start, subj_end, obj_start, obj_end):
                if token not in self.new_tokens:
                    self.new_tokens.append(token);
                    self.tokenizer.add_tokens([token]);

        # original adaptation from: https://arxiv.org/pdf/2102.01373v4
        elif input_format == 'typed_entity_marker_punct':
            subj_type = self.tokenizer.tokenize(subj_type.replace("_", " ").lower())
            obj_type = self.tokenizer.tokenize(obj_type.replace("_", " ").lower())

        # approach #4: adding a single PoS tag 
        elif input_format == 'typed_entity_marker_pos_punct':
            subj_first_pos = pos_tags[ss];
            obj_first_pos = pos_tags[os];
            subj_type = subj_type.replace("_", " ").lower()
            subj_type = self.tokenizer.tokenize(subj_type + "+" + subj_first_pos)
            obj_type = obj_type.replace("_", " ").lower()
            obj_type = self.tokenizer.tokenize(obj_type + "+" + obj_first_pos)

        # approach #5:
        elif input_format == 'typed_entity_marker_pos_seq_punct':
            # see approach #2
            subj_pos_tags = pos_tags[ss : se + 1];
            subj_pos_string = "+".join(subj_pos_tags);
            obj_pos_tags = pos_tags[os : oe + 1];
            obj_pos_string = "+".join(obj_pos_tags);
            # reuse part of originally adapted approach
            subj_type = subj_type.replace("_", " ").lower();
            obj_type = obj_type.replace("_", " ").lower();
            # concatenate PoS tags
            subj_type = self.tokenizer.tokenize(subj_type) + [':'] + self.tokenizer.tokenize(subj_pos_string);
            obj_type = self.tokenizer.tokenize(obj_type) + [':'] + self.tokenizer.tokenize(obj_pos_string);

        # approach #6:
        elif input_format == 'typed_entity_marker_pos_set_punct':
            # see approach #3
            subj_pos_tags = list(dict.fromkeys(pos_tags[ss : se + 1]));
            subj_pos_string = "+".join(subj_pos_tags);
            obj_pos_tags = list(dict.fromkeys(pos_tags[os : oe + 1]));
            obj_pos_string = "+".join(obj_pos_tags);
            # reuse part of originally adapted approach
            subj_type = subj_type.replace("_", " ").lower();
            obj_type = obj_type.replace("_", " ").lower();
            # concatenate PoS tags
            subj_type = self.tokenizer.tokenize(subj_type) + [":"] + self.tokenizer.tokenize(subj_pos_string);
            obj_type = self.tokenizer.tokenize(obj_type) + [":"] + self.tokenizer.tokenize(obj_pos_string);

        # Added new entity type mask procedures, etc; for each of the approaches.

        for i_t, token in enumerate(tokens):
            tokens_wordpiece = self.tokenizer.tokenize(token)

            if input_format == 'entity_mask':
                if ss <= i_t <= se or os <= i_t <= oe:
                    tokens_wordpiece = []
                    if i_t == ss:
                        new_ss = len(sents)
                        tokens_wordpiece = [subj_type]
                    if i_t == os:
                        new_os = len(sents)
                        tokens_wordpiece = [obj_type]

            elif input_format == 'entity_marker':
                if i_t == ss:
                    new_ss = len(sents)
                    tokens_wordpiece = ['[E1]'] + tokens_wordpiece
                if i_t == se:
                    tokens_wordpiece = tokens_wordpiece + ['[/E1]']
                if i_t == os:
                    new_os = len(sents)
                    tokens_wordpiece = ['[E2]'] + tokens_wordpiece
                if i_t == oe:
                    tokens_wordpiece = tokens_wordpiece + ['[/E2]']

            elif input_format == 'entity_marker_punct':
                if i_t == ss:
                    new_ss = len(sents)
                    tokens_wordpiece = ['@'] + tokens_wordpiece
                if i_t == se:
                    tokens_wordpiece = tokens_wordpiece + ['@']
                if i_t == os:
                    new_os = len(sents)
                    tokens_wordpiece = ['#'] + tokens_wordpiece
                if i_t == oe:
                    tokens_wordpiece = tokens_wordpiece + ['#']

            elif input_format == 'typed_entity_marker' or input_format == 'typed_entity_marker_pos' or input_format == 'typed_entity_marker_pos_seq' or input_format == 'typed_entity_marker_pos_set':
                if i_t == ss:
                    new_ss = len(sents)
                    tokens_wordpiece = [subj_start] + tokens_wordpiece
                if i_t == se:
                    tokens_wordpiece = tokens_wordpiece + [subj_end]
                if i_t == os:
                    new_os = len(sents)
                    tokens_wordpiece = [obj_start] + tokens_wordpiece
                if i_t == oe:
                    tokens_wordpiece = tokens_wordpiece + [obj_end]

            elif input_format == 'typed_entity_marker_punct':
                if i_t == ss:
                    new_ss = len(sents)
                    tokens_wordpiece = ['@'] + ['*'] + subj_type + ['*'] + tokens_wordpiece
                if i_t == se:
                    tokens_wordpiece = tokens_wordpiece + ['@']
                if i_t == os:
                    new_os = len(sents)
                    tokens_wordpiece = ["#"] + ['^'] + obj_type + ['^'] + tokens_wordpiece
                if i_t == oe:
                    tokens_wordpiece = tokens_wordpiece + ["#"]

            elif input_format == 'typed_entity_marker_pos_punct' or input_format == 'typed_entity_marker_pos_seq_punct' or input_format == 'typed_entity_marker_pos_set_punct':
                if i_t == ss:
                    new_ss = len(sents)
                    tokens_wordpiece = ['@'] + ['*'] + subj_type + ['*'] + tokens_wordpiece
                if i_t == se:
                    tokens_wordpiece = tokens_wordpiece + ['@']
                if i_t == os:
                    new_os = len(sents)
                    tokens_wordpiece = ["#"] + ['^'] + obj_type + ['^'] + tokens_wordpiece
                if i_t == oe:
                    tokens_wordpiece = tokens_wordpiece + ["#"]

                print(tokens_wordpiece);

            print(tokens_wordpiece);
            sents.extend(tokens_wordpiece)
            print("sents: ");
            print(sents);
        sents = sents[:self.args.max_seq_length - 2]
        print(sents);
        input_ids = self.tokenizer.convert_tokens_to_ids(sents)
        input_ids = self.tokenizer.build_inputs_with_special_tokens(input_ids)
        print(input_ids);
        # print(new_ss + 1);
        print(new_os + 1);
        return input_ids, new_ss + 1, new_os + 1


class TACREDProcessor(Processor):
    def __init__(self, args, tokenizer):
        super().__init__(args, tokenizer)
        self.LABEL_TO_ID = {'no_relation': 0, 'per:title': 1, 'org:top_members/employees': 2, 'per:employee_of': 3, 'org:alternate_names': 4, 'org:country_of_headquarters': 5, 'per:countries_of_residence': 6, 'org:city_of_headquarters': 7, 'per:cities_of_residence': 8, 'per:age': 9, 'per:stateorprovinces_of_residence': 10, 'per:origin': 11, 'org:subsidiaries': 12, 'org:parents': 13, 'per:spouse': 14, 'org:stateorprovince_of_headquarters': 15, 'per:children': 16, 'per:other_family': 17, 'per:alternate_names': 18, 'org:members': 19, 'per:siblings': 20, 'per:schools_attended': 21, 'per:parents': 22, 'per:date_of_death': 23, 'org:member_of': 24, 'org:founded_by': 25, 'org:website': 26, 'per:cause_of_death': 27, 'org:political/religious_affiliation': 28, 'org:founded': 29, 'per:city_of_death': 30, 'org:shareholders': 31, 'org:number_of_employees/members': 32, 'per:date_of_birth': 33, 'per:city_of_birth': 34, 'per:charges': 35, 'per:stateorprovince_of_death': 36, 'per:religion': 37, 'per:stateorprovince_of_birth': 38, 'per:country_of_birth': 39, 'org:dissolved': 40, 'per:country_of_death': 41}

    def read(self, file_in):
        features = []
        with open(file_in, "r") as fh:
            data = json.load(fh)

        for d in tqdm(data):
            ss, se = d['subj_start'], d['subj_end']
            os, oe = d['obj_start'], d['obj_end']

            tokens = d['token']
            tokens = [convert_token(token) for token in tokens]

            # modified tokenize to also accept the PoS tags, it's important to understand that whilst the subj_type & obj_type are a single token, i.e. 'person' or 'organisation'
            # the PoS tags could be a list of length > 1. This may cause some issues when representing the the start-subject, end-subject, start-object & end-object as
            # their own distinct tags (i.e. [SUB-PERSON-NNP-NNP-NNP] jon anthony dil [/SUB-PERSON-NNP-NNP-NNP]) due to the creeping tag length
            # Further: using an alternative representation may shorten the observable context, i.e. '@ * person : nnp + nnp + nnp * jon anthony dil @'
            # TODO: go back and read through the papers again on the various models we're using here to understand the implications of these various changes in more depth
            input_ids, new_ss, new_os = self.tokenize(tokens, d['subj_type'], d['obj_type'], ss, se, os, oe, pos_tags=d['stanford_pos']) # <-- CHANGES # pos_tags=d['stanford_pos']
            rel = self.LABEL_TO_ID[d['relation']]

            feature = {
                'input_ids': input_ids,
                'labels': rel,
                'ss': new_ss,
                'os': new_os,
            }

            features.append(feature)
        return features


class RETACREDProcessor(Processor):
    def __init__(self, args, tokenizer):
        super().__init__(args, tokenizer)
        self.LABEL_TO_ID = {'no_relation': 0, 'org:founded_by': 1, 'per:identity': 2, 'org:alternate_names': 3, 'per:children': 4, 'per:origin': 5, 'per:countries_of_residence': 6, 'per:employee_of': 7, 'per:title': 8, 'org:city_of_branch': 9, 'per:religion': 10, 'per:age': 11, 'per:date_of_death': 12, 'org:website': 13, 'per:stateorprovinces_of_residence': 14, 'org:top_members/employees': 15, 'org:number_of_employees/members': 16, 'org:members': 17, 'org:country_of_branch': 18, 'per:spouse': 19, 'org:stateorprovince_of_branch': 20, 'org:political/religious_affiliation': 21, 'org:member_of': 22, 'per:siblings': 23, 'per:stateorprovince_of_birth': 24, 'org:dissolved': 25, 'per:other_family': 26, 'org:shareholders': 27, 'per:parents': 28, 'per:charges': 29, 'per:schools_attended': 30, 'per:cause_of_death': 31, 'per:city_of_death': 32, 'per:stateorprovince_of_death': 33, 'org:founded': 34, 'per:country_of_death': 35, 'per:country_of_birth': 36, 'per:date_of_birth': 37, 'per:cities_of_residence': 38, 'per:city_of_birth': 39}

    def read(self, file_in):
        features = []
        with open(file_in, "r") as fh:
            data = json.load(fh)

        for d in tqdm(data):
            ss, se = d['subj_start'], d['subj_end']
            os, oe = d['obj_start'], d['obj_end']

            tokens = d['token']
            tokens = [convert_token(token) for token in tokens]

            # modified tokenize to also accept the PoS tags
            input_ids, new_ss, new_os = self.tokenize(tokens, d['subj_type'], d['obj_type'], ss, se, os, oe, pos_tags=d['stanford_pos']) # <-- CHANGES # pos_tags=d['stanford_pos']
            rel = self.LABEL_TO_ID[d['relation']]

            feature = {
                'input_ids': input_ids,
                'labels': rel,
                'ss': new_ss,
                'os': new_os,
            }

            print(feature);

            features.append(feature)
        return features
# Out:
# <>:42: SyntaxWarning: invalid escape sequence '\i'
# <>:42: SyntaxWarning: invalid escape sequence '\i'
# /tmp/ipykernel_99685/4292977493.py:42: SyntaxWarning: invalid escape sequence '\i'
#   """

# %% [markdown]
# ### Section 1: Observing the Tokenisation Process for Intuition
#
# Firstly, we load samples of the train, dev and test sets (n=3), then observe the tokenisation process as they're being read in by the processor. This provides some concrete intuition as to the masking process being described within the paper (Zhou et al. 2022). Shortly thereafer, we apply the same strategy to observe the various changes that have been made to the tokenisation strategies and their newly defined variants.

# %%
# load train, test, dev (samples=3)
train_file = os.path.join("./train_examples.json");
dev_file = os.path.join("./dev_examples.json");
test_file = os.path.join("./test_examples.json");

# load standard tokenised for bert
tokenizer = AutoTokenizer.from_pretrained(
    "bert-base-cased"
);

# a 'naive' service-container type pattern
class ArgumentsContainer:
  max_seq_length = 512;
  input_format = "typed_entity_marker_punct";

  def __init__(self, args, tokenizer):
    super().__init__();
    self.args = args;
    self.tokenizer = tokenizer;
    self.input_format = "typed_entity_marker_punct";
    self.max_seq_length: 512;

  def set_input_format(self, newFormat):
    self.input_format = newFormat;

  def get_input_format(self):
    return self.input_format;

args = {
  'input_format': "typed_entity_marker_punct",
  'max_seq_length': 128
};

# instanciate the RETACREDProcessor used during training
arguments = ArgumentsContainer(args, tokenizer)
processor = RETACREDProcessor(arguments, tokenizer)

# observe the process for building input representations
train_features = processor.read(train_file)
dev_features = processor.read(dev_file)
test_features = processor.read(test_file)
# Out:
# /home/jon/anaconda3/envs/ml-env/lib/python3.12/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 100%|██████████| 3/3 [00:00<00:00, 1496.36it/s]
# ['#', '^', 'person', '^', 'Tom']
# sents:
# ['#', '^', 'person', '^', 'Tom']
# ['T', '##hab', '##ane', '#']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#']
# ['resigned']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned']
# ['in']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in']
# ['October']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October']
# ['last']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last']
# ['year']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year']
# ['to']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to']
# ['form']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form']
# ['the']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the']
# ['@', '*', 'organization', '*', 'All']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All']
# ['Ba', '##so', '##th', '##o']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o']
# ['Convention', '@']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@']
# ['(']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(']
# ['ABC']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC']
# [')']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')']
# [',']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',']
# ['crossing']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing']
# ['the']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the']
# ['floor']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor']
# ['with']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with']
# ['17']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17']
# ['members']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members']
# ['of']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of']
# ['parliament']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament']
# [',']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',']
# ['causing']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing']
# ['constitutional']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional']
# ['monarch']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch']
# ['King']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King']
# ['Let', '##sie']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie']
# ['III']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III']
# ['to']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to']
# ['dissolve']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve']
# ['parliament']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament']
# ['and']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and']
# ['call']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and', 'call']
# ['the']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and', 'call', 'the']
# ['snap']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and', 'call', 'the', 'snap']
# ['election']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and', 'call', 'the', 'snap', 'election']
# ['.']
# sents:
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and', 'call', 'the', 'snap', 'election', '.']
# ['#', '^', 'person', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and', 'call', 'the', 'snap', 'election', '.']
# [101, 108, 167, 1825, 167, 2545, 157, 17266, 6354, 108, 4603, 1107, 1357, 1314, 1214, 1106, 1532, 1103, 137, 115, 2369, 115, 1398, 18757, 7301, 1582, 1186, 5818, 137, 113, 5254, 114, 117, 4905, 1103, 1837, 1114, 1542, 1484, 1104, 6254, 117, 3989, 7950, 14390, 1624, 2421, 9819, 2684, 1106, 24907, 6254, 1105, 1840, 1103, 11152, 1728, 119, 102]
# 1
# {'input_ids': [101, 108, 167, 1825, 167, 2545, 157, 17266, 6354, 108, 4603, 1107, 1357, 1314, 1214, 1106, 1532, 1103, 137, 115, 2369, 115, 1398, 18757, 7301, 1582, 1186, 5818, 137, 113, 5254, 114, 117, 4905, 1103, 1837, 1114, 1542, 1484, 1104, 6254, 117, 3989, 7950, 14390, 1624, 2421, 9819, 2684, 1106, 24907, 6254, 1105, 1840, 1103, 11152, 1728, 119, 102], 'labels': 1, 'ss': 18, 'os': 1}
# ['In']
# sents:
# ['In']
# ['1983']
# sents:
# ['In', '1983']
# [',']
# sents:
# ['In', '1983', ',']
# ['a']
# sents:
# ['In', '1983', ',', 'a']
# ['year']
# sents:
# ['In', '1983', ',', 'a', 'year']
# ['after']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after']
# ['the']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the']
# ['rally']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally']
# [',']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',']
# ['@', '*', 'person', '*', 'For', '##sberg', '@']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@']
# ['received']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received']
# ['the']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the']
# ['so', '-', 'called']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called']
# ['`', '`']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`']
# ['genius']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius']
# ['award']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award']
# ["'", "'"]
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'"]
# ['from']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from']
# ['the']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the']
# ['#', '^', 'person', '^', 'John']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', '^', 'John']
# ['D', '.', '#']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', '^', 'John', 'D', '.', '#']
# ['and']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', '^', 'John', 'D', '.', '#', 'and']
# ['Catherine']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', '^', 'John', 'D', '.', '#', 'and', 'Catherine']
# ['T', '.']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', '^', 'John', 'D', '.', '#', 'and', 'Catherine', 'T', '.']
# ['MacArthur']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', '^', 'John', 'D', '.', '#', 'and', 'Catherine', 'T', '.', 'MacArthur']
# ['Foundation']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', '^', 'John', 'D', '.', '#', 'and', 'Catherine', 'T', '.', 'MacArthur', 'Foundation']
# ['.']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', '^', 'John', 'D', '.', '#', 'and', 'Catherine', 'T', '.', 'MacArthur', 'Foundation', '.']
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', '^', 'John', 'D', '.', '#', 'and', 'Catherine', 'T', '.', 'MacArthur', 'Foundation', '.']
# [101, 1130, 2278, 117, 170, 1214, 1170, 1103, 11158, 117, 137, 115, 1825, 115, 1370, 19945, 137, 1460, 1103, 1177, 118, 1270, 169, 169, 13533, 2574, 112, 112, 1121, 1103, 108, 167, 1825, 167, 1287, 141, 119, 108, 1105, 6017, 157, 119, 21045, 2974, 119, 102]
# 30
# {'input_ids': [101, 1130, 2278, 117, 170, 1214, 1170, 1103, 11158, 117, 137, 115, 1825, 115, 1370, 19945, 137, 1460, 1103, 1177, 118, 1270, 169, 169, 13533, 2574, 112, 112, 1121, 1103, 108, 167, 1825, 167, 1287, 141, 119, 108, 1105, 6017, 157, 119, 21045, 2974, 119, 102], 'labels': 0, 'ss': 10, 'os': 30}
# ['This']
# sents:
# ['This']
# ['was']
# sents:
# ['This', 'was']
# ['among']
# sents:
# ['This', 'was', 'among']
# ['a']
# sents:
# ['This', 'was', 'among', 'a']
# ['batch']
# sents:
# ['This', 'was', 'among', 'a', 'batch']
# ['of']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of']
# ['paperback']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback']
# ['#', '^', 'organization', '^', 'Oxford']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford']
# ['World', '#']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#']
# ["'", 's']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's']
# ['Classics']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics']
# ['that']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that']
# ['I']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I']
# ['was']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was']
# ['given']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given']
# ['as']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as']
# ['a']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a']
# ['reward']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward']
# ['for']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for']
# ['reading']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading']
# ['and']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and']
# ['commenting']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting']
# ['on']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on']
# ['a']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on', 'a']
# ['manuscript']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on', 'a', 'manuscript']
# ['for']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on', 'a', 'manuscript', 'for']
# ['@', '*', 'organization', '*', 'O', '##UP', '@']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on', 'a', 'manuscript', 'for', '@', '*', 'organization', '*', 'O', '##UP', '@']
# ['.']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on', 'a', 'manuscript', 'for', '@', '*', 'organization', '*', 'O', '##UP', '@', '.']
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on', 'a', 'manuscript', 'for', '@', '*', 'organization', '*', 'O', '##UP', '@', '.']
# [101, 1188, 1108, 1621, 170, 15817, 1104, 16885, 108, 167, 2369, 167, 3500, 1291, 108, 112, 188, 14387, 1115, 146, 1108, 1549, 1112, 170, 10703, 1111, 3455, 1105, 18912, 1113, 170, 8323, 1111, 137, 115, 2369, 115, 152, 18124, 137, 119, 102]
# 8
# {'input_ids': [101, 1188, 1108, 1621, 170, 15817, 1104, 16885, 108, 167, 2369, 167, 3500, 1291, 108, 112, 188, 14387, 1115, 146, 1108, 1549, 1112, 170, 10703, 1111, 3455, 1105, 18912, 1113, 170, 8323, 1111, 137, 115, 2369, 115, 152, 18124, 137, 119, 102], 'labels': 0, 'ss': 33, 'os': 8}
# 100%|██████████| 3/3 [00:00<00:00, 1546.00it/s]
# ['At']
# sents:
# ['At']
# ['the']
# sents:
# ['At', 'the']
# ['same']
# sents:
# ['At', 'the', 'same']
# ['time']
# sents:
# ['At', 'the', 'same', 'time']
# [',']
# sents:
# ['At', 'the', 'same', 'time', ',']
# ['Chief']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief']
# ['Financial']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial']
# ['Officer']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer']
# ['@', '*', 'person', '*', 'Douglas']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas']
# ['Flint', '@']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@']
# ['will']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will']
# ['become']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become']
# ['#', '^', 'title', '^', 'chairman', '#']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#']
# [',']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',']
# ['succeeding']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding']
# ['Stephen']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding', 'Stephen']
# ['Green']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding', 'Stephen', 'Green']
# ['who']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding', 'Stephen', 'Green', 'who']
# ['is']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding', 'Stephen', 'Green', 'who', 'is']
# ['leaving']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding', 'Stephen', 'Green', 'who', 'is', 'leaving']
# ['to']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding', 'Stephen', 'Green', 'who', 'is', 'leaving', 'to']
# ['take']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding', 'Stephen', 'Green', 'who', 'is', 'leaving', 'to', 'take']
# ['a']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding', 'Stephen', 'Green', 'who', 'is', 'leaving', 'to', 'take', 'a']
# ['government']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding', 'Stephen', 'Green', 'who', 'is', 'leaving', 'to', 'take', 'a', 'government']
# ['job']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding', 'Stephen', 'Green', 'who', 'is', 'leaving', 'to', 'take', 'a', 'government', 'job']
# ['.']
# sents:
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding', 'Stephen', 'Green', 'who', 'is', 'leaving', 'to', 'take', 'a', 'government', 'job', '.']
# ['At', 'the', 'same', 'time', ',', 'Chief', 'Financial', 'Officer', '@', '*', 'person', '*', 'Douglas', 'Flint', '@', 'will', 'become', '#', '^', 'title', '^', 'chairman', '#', ',', 'succeeding', 'Stephen', 'Green', 'who', 'is', 'leaving', 'to', 'take', 'a', 'government', 'job', '.']
# [101, 1335, 1103, 1269, 1159, 117, 2534, 7748, 4124, 137, 115, 1825, 115, 4402, 17741, 137, 1209, 1561, 108, 167, 1641, 167, 3931, 108, 117, 13605, 3620, 2565, 1150, 1110, 2128, 1106, 1321, 170, 1433, 2261, 119, 102]
# 18
# {'input_ids': [101, 1335, 1103, 1269, 1159, 117, 2534, 7748, 4124, 137, 115, 1825, 115, 4402, 17741, 137, 1209, 1561, 108, 167, 1641, 167, 3931, 108, 117, 13605, 3620, 2565, 1150, 1110, 2128, 1106, 1321, 170, 1433, 2261, 119, 102], 'labels': 8, 'ss': 9, 'os': 18}
# ['U', '.', 'S', '.']
# sents:
# ['U', '.', 'S', '.']
# ['District']
# sents:
# ['U', '.', 'S', '.', 'District']
# ['Court']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court']
# ['Judge']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge']
# ['#', '^', 'person', '^', 'Jeffrey']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey']
# ['White', '#']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#']
# ['in']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in']
# ['mid', '-', 'February']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February']
# ['issued']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued']
# ['an']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an']
# ['injunction']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction']
# ['against']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against']
# ['W', '##iki', '##lea', '##ks']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks']
# ['after']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after']
# ['the']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the']
# ['Zurich', '-', 'based']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based']
# ['Bank']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank']
# ['@', '*', 'person', '*', 'Julius']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius']
# ['Ba', '##er', '@']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@']
# ['accused']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused']
# ['the']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the']
# ['site']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site']
# ['of']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of']
# ['posting']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of', 'posting']
# ['sensitive']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of', 'posting', 'sensitive']
# ['account']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of', 'posting', 'sensitive', 'account']
# ['information']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of', 'posting', 'sensitive', 'account', 'information']
# ['stolen']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of', 'posting', 'sensitive', 'account', 'information', 'stolen']
# ['by']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of', 'posting', 'sensitive', 'account', 'information', 'stolen', 'by']
# ['a']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of', 'posting', 'sensitive', 'account', 'information', 'stolen', 'by', 'a']
# ['di', '##s', '##g', '##run', '##tled']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of', 'posting', 'sensitive', 'account', 'information', 'stolen', 'by', 'a', 'di', '##s', '##g', '##run', '##tled']
# ['former']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of', 'posting', 'sensitive', 'account', 'information', 'stolen', 'by', 'a', 'di', '##s', '##g', '##run', '##tled', 'former']
# ['employee']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of', 'posting', 'sensitive', 'account', 'information', 'stolen', 'by', 'a', 'di', '##s', '##g', '##run', '##tled', 'former', 'employee']
# ['.']
# sents:
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of', 'posting', 'sensitive', 'account', 'information', 'stolen', 'by', 'a', 'di', '##s', '##g', '##run', '##tled', 'former', 'employee', '.']
# ['U', '.', 'S', '.', 'District', 'Court', 'Judge', '#', '^', 'person', '^', 'Jeffrey', 'White', '#', 'in', 'mid', '-', 'February', 'issued', 'an', 'injunction', 'against', 'W', '##iki', '##lea', '##ks', 'after', 'the', 'Zurich', '-', 'based', 'Bank', '@', '*', 'person', '*', 'Julius', 'Ba', '##er', '@', 'accused', 'the', 'site', 'of', 'posting', 'sensitive', 'account', 'information', 'stolen', 'by', 'a', 'di', '##s', '##g', '##run', '##tled', 'former', 'employee', '.']
# [101, 158, 119, 156, 119, 1574, 2031, 5274, 108, 167, 1825, 167, 10708, 2061, 108, 1107, 2286, 118, 1428, 3010, 1126, 25905, 1222, 160, 12635, 19094, 4616, 1170, 1103, 16142, 118, 1359, 2950, 137, 115, 1825, 115, 10315, 18757, 1200, 137, 4806, 1103, 1751, 1104, 15537, 7246, 3300, 1869, 7251, 1118, 170, 4267, 1116, 1403, 10607, 16271, 1393, 7775, 119, 102]
# 8
# {'input_ids': [101, 158, 119, 156, 119, 1574, 2031, 5274, 108, 167, 1825, 167, 10708, 2061, 108, 1107, 2286, 118, 1428, 3010, 1126, 25905, 1222, 160, 12635, 19094, 4616, 1170, 1103, 16142, 118, 1359, 2950, 137, 115, 1825, 115, 10315, 18757, 1200, 137, 4806, 1103, 1751, 1104, 15537, 7246, 3300, 1869, 7251, 1118, 170, 4267, 1116, 1403, 10607, 16271, 1393, 7775, 119, 102], 'labels': 0, 'ss': 33, 'os': 8}
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#']
# ['2009', '-', '07', '-', '07']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07']
# ['11', ':', '07', ':', '32']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32']
# ['UTC']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC']
# ['French']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French']
# ['media']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media']
# ['earlier']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier']
# ['reported']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported']
# ['that']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that']
# ['@', '*', 'person', '*', 'Mont', '##court', '@']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@']
# [',']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',']
# ['ranked']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked']
# ['119']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119']
# [',']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',']
# ['was']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was']
# ['found']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found']
# ['dead']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found', 'dead']
# ['by']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found', 'dead', 'by']
# ['his']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found', 'dead', 'by', 'his']
# ['girlfriend']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found', 'dead', 'by', 'his', 'girlfriend']
# ['in']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found', 'dead', 'by', 'his', 'girlfriend', 'in']
# ['the']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found', 'dead', 'by', 'his', 'girlfriend', 'in', 'the']
# ['stairwell']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found', 'dead', 'by', 'his', 'girlfriend', 'in', 'the', 'stairwell']
# ['of']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found', 'dead', 'by', 'his', 'girlfriend', 'in', 'the', 'stairwell', 'of']
# ['his']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found', 'dead', 'by', 'his', 'girlfriend', 'in', 'the', 'stairwell', 'of', 'his']
# ['Paris']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found', 'dead', 'by', 'his', 'girlfriend', 'in', 'the', 'stairwell', 'of', 'his', 'Paris']
# ['apartment']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found', 'dead', 'by', 'his', 'girlfriend', 'in', 'the', 'stairwell', 'of', 'his', 'Paris', 'apartment']
# ['.']
# sents:
# ['#', '^', 'city', '^', 'PA', '##RI', '##S', '#', '2009', '-', '07', '-', '07', '11', ':', '07', ':', '32', 'UTC', 'French', 'media', 'earlier', 'reported', 'that', '@', '*', 'person', '*', 'Mont', '##court', '@', ',', 'ranked', '119', ',', 'was', 'found', 'dead', 'by', 'his', 'girlfriend', 'in', 'the', 'stairwell', 'of', 'his', 'Paris', 'apartment', '.']
# ...
# ['Corporation']
# sents:
# ['He', 'has', 'served', 'as', 'a', 'policy', 'aide', 'to', 'the', 'late', 'U', '.', 'S', '.', 'Senator', 'Alan', 'C', '##ran', '##ston', ',', 'as', 'National', 'Issues', 'Director', 'for', 'the', '2004', 'presidential', 'campaign', 'of', 'Congressman', 'Dennis', 'Ku', '##cini', '##ch', ',', 'as', 'a', 'co', '-', 'founder', 'of', '@', '*', 'organization', '*', 'Progressive', 'Democrats', 'of', 'America', '@', 'and', 'as', 'a', 'member', 'of', 'the', '#', '^', 'organization', '^', 'international', 'policy', 'department', '#', 'at', 'the', 'RA', '##ND', 'Corporation']
# ['think']
# sents:
# ['He', 'has', 'served', 'as', 'a', 'policy', 'aide', 'to', 'the', 'late', 'U', '.', 'S', '.', 'Senator', 'Alan', 'C', '##ran', '##ston', ',', 'as', 'National', 'Issues', 'Director', 'for', 'the', '2004', 'presidential', 'campaign', 'of', 'Congressman', 'Dennis', 'Ku', '##cini', '##ch', ',', 'as', 'a', 'co', '-', 'founder', 'of', '@', '*', 'organization', '*', 'Progressive', 'Democrats', 'of', 'America', '@', 'and', 'as', 'a', 'member', 'of', 'the', '#', '^', 'organization', '^', 'international', 'policy', 'department', '#', 'at', 'the', 'RA', '##ND', 'Corporation', 'think']
# ['tank']
# sents:
# ['He', 'has', 'served', 'as', 'a', 'policy', 'aide', 'to', 'the', 'late', 'U', '.', 'S', '.', 'Senator', 'Alan', 'C', '##ran', '##ston', ',', 'as', 'National', 'Issues', 'Director', 'for', 'the', '2004', 'presidential', 'campaign', 'of', 'Congressman', 'Dennis', 'Ku', '##cini', '##ch', ',', 'as', 'a', 'co', '-', 'founder', 'of', '@', '*', 'organization', '*', 'Progressive', 'Democrats', 'of', 'America', '@', 'and', 'as', 'a', 'member', 'of', 'the', '#', '^', 'organization', '^', 'international', 'policy', 'department', '#', 'at', 'the', 'RA', '##ND', 'Corporation', 'think', 'tank']
# ['before']
# sents:
# ['He', 'has', 'served', 'as', 'a', 'policy', 'aide', 'to', 'the', 'late', 'U', '.', 'S', '.', 'Senator', 'Alan', 'C', '##ran', '##ston', ',', 'as', 'National', 'Issues', 'Director', 'for', 'the', '2004', 'presidential', 'campaign', 'of', 'Congressman', 'Dennis', 'Ku', '##cini', '##ch', ',', 'as', 'a', 'co', '-', 'founder', 'of', '@', '*', 'organization', '*', 'Progressive', 'Democrats', 'of', 'America', '@', 'and', 'as', 'a', 'member', 'of', 'the', '#', '^', 'organization', '^', 'international', 'policy', 'department', '#', 'at', 'the', 'RA', '##ND', 'Corporation', 'think', 'tank', 'before']
# ['all']
# sents:
# ['He', 'has', 'served', 'as', 'a', 'policy', 'aide', 'to', 'the', 'late', 'U', '.', 'S', '.', 'Senator', 'Alan', 'C', '##ran', '##ston', ',', 'as', 'National', 'Issues', 'Director', 'for', 'the', '2004', 'presidential', 'campaign', 'of', 'Congressman', 'Dennis', 'Ku', '##cini', '##ch', ',', 'as', 'a', 'co', '-', 'founder', 'of', '@', '*', 'organization', '*', 'Progressive', 'Democrats', 'of', 'America', '@', 'and', 'as', 'a', 'member', 'of', 'the', '#', '^', 'organization', '^', 'international', 'policy', 'department', '#', 'at', 'the', 'RA', '##ND', 'Corporation', 'think', 'tank', 'before', 'all']
# ['that']
# sents:
# ['He', 'has', 'served', 'as', 'a', 'policy', 'aide', 'to', 'the', 'late', 'U', '.', 'S', '.', 'Senator', 'Alan', 'C', '##ran', '##ston', ',', 'as', 'National', 'Issues', 'Director', 'for', 'the', '2004', 'presidential', 'campaign', 'of', 'Congressman', 'Dennis', 'Ku', '##cini', '##ch', ',', 'as', 'a', 'co', '-', 'founder', 'of', '@', '*', 'organization', '*', 'Progressive', 'Democrats', 'of', 'America', '@', 'and', 'as', 'a', 'member', 'of', 'the', '#', '^', 'organization', '^', 'international', 'policy', 'department', '#', 'at', 'the', 'RA', '##ND', 'Corporation', 'think', 'tank', 'before', 'all', 'that']
# ['.']
# sents:
# ['He', 'has', 'served', 'as', 'a', 'policy', 'aide', 'to', 'the', 'late', 'U', '.', 'S', '.', 'Senator', 'Alan', 'C', '##ran', '##ston', ',', 'as', 'National', 'Issues', 'Director', 'for', 'the', '2004', 'presidential', 'campaign', 'of', 'Congressman', 'Dennis', 'Ku', '##cini', '##ch', ',', 'as', 'a', 'co', '-', 'founder', 'of', '@', '*', 'organization', '*', 'Progressive', 'Democrats', 'of', 'America', '@', 'and', 'as', 'a', 'member', 'of', 'the', '#', '^', 'organization', '^', 'international', 'policy', 'department', '#', 'at', 'the', 'RA', '##ND', 'Corporation', 'think', 'tank', 'before', 'all', 'that', '.']
# ['He', 'has', 'served', 'as', 'a', 'policy', 'aide', 'to', 'the', 'late', 'U', '.', 'S', '.', 'Senator', 'Alan', 'C', '##ran', '##ston', ',', 'as', 'National', 'Issues', 'Director', 'for', 'the', '2004', 'presidential', 'campaign', 'of', 'Congressman', 'Dennis', 'Ku', '##cini', '##ch', ',', 'as', 'a', 'co', '-', 'founder', 'of', '@', '*', 'organization', '*', 'Progressive', 'Democrats', 'of', 'America', '@', 'and', 'as', 'a', 'member', 'of', 'the', '#', '^', 'organization', '^', 'international', 'policy', 'department', '#', 'at', 'the', 'RA', '##ND', 'Corporation', 'think', 'tank', 'before', 'all', 'that', '.']
# [101, 1124, 1144, 1462, 1112, 170, 2818, 17512, 1106, 1103, 1523, 158, 119, 156, 119, 5293, 4258, 140, 4047, 6186, 117, 1112, 1305, 21213, 2524, 1111, 1103, 1516, 5200, 2322, 1104, 15444, 6277, 23209, 27909, 1732, 117, 1112, 170, 1884, 118, 3249, 1104, 137, 115, 2369, 115, 10709, 7834, 1104, 1738, 137, 1105, 1112, 170, 1420, 1104, 1103, 108, 167, 2369, 167, 1835, 2818, 2853, 108, 1120, 1103, 26547, 16769, 3436, 1341, 4890, 1196, 1155, 1115, 119, 102]
# 58
# {'input_ids': [101, 1124, 1144, 1462, 1112, 170, 2818, 17512, 1106, 1103, 1523, 158, 119, 156, 119, 5293, 4258, 140, 4047, 6186, 117, 1112, 1305, 21213, 2524, 1111, 1103, 1516, 5200, 2322, 1104, 15444, 6277, 23209, 27909, 1732, 117, 1112, 170, 1884, 118, 3249, 1104, 137, 115, 2369, 115, 10709, 7834, 1104, 1738, 137, 1105, 1112, 170, 1420, 1104, 1103, 108, 167, 2369, 167, 1835, 2818, 2853, 108, 1120, 1103, 26547, 16769, 3436, 1341, 4890, 1196, 1155, 1115, 119, 102], 'labels': 0, 'ss': 43, 'os': 58}
# ['Me', '##ssin', '##a']
# sents:
# ['Me', '##ssin', '##a']
# ['Den', '##aro']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro']
# ['has']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has']
# ['been']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been']
# ['trying']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying']
# ['to']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to']
# ['impose']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose']
# ['@', '*', 'person', '*', 'his', '@']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@']
# ['power']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power']
# ['in']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in']
# ['#', '^', 'city', '^', 'Palermo', '#']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#']
# [',']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',']
# ['the']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the']
# ['Sicilian']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian']
# ['capital']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital']
# [',']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',']
# ['and']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and']
# ['become']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become']
# ['the']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the']
# ['new']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new']
# ['head']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head']
# ['of']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of']
# ['the']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the']
# ['Sicilian']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian']
# ['Mafia']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia']
# [',']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia', ',']
# ['weakened']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia', ',', 'weakened']
# ['by']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia', ',', 'weakened', 'by']
# ['the']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia', ',', 'weakened', 'by', 'the']
# ['arrest']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia', ',', 'weakened', 'by', 'the', 'arrest']
# ['of']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia', ',', 'weakened', 'by', 'the', 'arrest', 'of']
# ['Pro', '##ven', '##zano']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia', ',', 'weakened', 'by', 'the', 'arrest', 'of', 'Pro', '##ven', '##zano']
# ['in']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia', ',', 'weakened', 'by', 'the', 'arrest', 'of', 'Pro', '##ven', '##zano', 'in']
# ['April']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia', ',', 'weakened', 'by', 'the', 'arrest', 'of', 'Pro', '##ven', '##zano', 'in', 'April']
# ['2006']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia', ',', 'weakened', 'by', 'the', 'arrest', 'of', 'Pro', '##ven', '##zano', 'in', 'April', '2006']
# ['.']
# sents:
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia', ',', 'weakened', 'by', 'the', 'arrest', 'of', 'Pro', '##ven', '##zano', 'in', 'April', '2006', '.']
# ['Me', '##ssin', '##a', 'Den', '##aro', 'has', 'been', 'trying', 'to', 'impose', '@', '*', 'person', '*', 'his', '@', 'power', 'in', '#', '^', 'city', '^', 'Palermo', '#', ',', 'the', 'Sicilian', 'capital', ',', 'and', 'become', 'the', 'new', 'head', 'of', 'the', 'Sicilian', 'Mafia', ',', 'weakened', 'by', 'the', 'arrest', 'of', 'Pro', '##ven', '##zano', 'in', 'April', '2006', '.']
# [101, 2508, 21543, 1161, 14760, 14452, 1144, 1151, 1774, 1106, 19103, 137, 115, 1825, 115, 1117, 137, 1540, 1107, 108, 167, 1331, 167, 20250, 108, 117, 1103, 25150, 2364, 117, 1105, 1561, 1103, 1207, 1246, 1104, 1103, 25150, 18070, 117, 12041, 1118, 1103, 6040, 1104, 5096, 7912, 23371, 1107, 1364, 1386, 119, 102]
# 19
# {'input_ids': [101, 2508, 21543, 1161, 14760, 14452, 1144, 1151, 1774, 1106, 19103, 137, 115, 1825, 115, 1117, 137, 1540, 1107, 108, 167, 1331, 167, 20250, 108, 117, 1103, 25150, 2364, 117, 1105, 1561, 1103, 1207, 1246, 1104, 1103, 25150, 18070, 117, 12041, 1118, 1103, 6040, 1104, 5096, 7912, 23371, 1107, 1364, 1386, 119, 102], 'labels': 0, 'ss': 11, 'os': 19}

# %%
#  Implement the following input formats:
#     - entity_mask: [SUBJ-NER], [OBJ-NER].
#     - entity_marker: [E1] subject [/E1], [E2] object [/E2].
#     - entity_marker_punct: @ subject @, # object #.
#     - typed_entity_marker: [SUBJ-NER] subject [/SUBJ-NER], [OBJ-NER] obj [/OBJ-NER]
#     - typed_entity_marker_punct: @ * subject ner type * subject @, # ^ object ner type ^ object #
#     - typed_entity_marker_pos: [SUBJ-NER*POS1] subject [/SUBJ-NER*POS1], [OBJ-NER*POS1] obj [/OBJ-NER*POS1] <-- Appends the first PoS tag to the marker
#     - typed_entity_marker_pos_seq: [SUBJ-NER*POS1+POS2] subject [/SUBJ-NER*POS1+POS2], [OBJ-NER*POS1+POS2] obj [/OBJ-NER*POS1+POS2] <-- Appends all PoS tags \in multiset(entity_{POStags})
#     - typed_entity_marker_pos_set: [SUBJ-NER*UNIQUEPOS1+UNIQUEPOS2] subject [/SUBJ-NER*UNIQUEPOS1+UNIQUEPOS2], [OBJ-NER*UNIQUEPOS1+UNIQUEPOS2] obj [/OBJ-NER*UNIQUEPOS1+UNIQUEPOS2] <-- Appends all PoS tags \in set(entity_{POStags})
#     - typed_entity_marker_pos_punct: @ * subject ner type + pos tag * subject @, # ^ object ner type pos tag ^ object # <-- Appends first PoS tag using punct representation
#     - typed_entity_marker_pos_seq_punct: @ * subject ner type + pos_1 + pos_2 * subject_{token_{1}} subject_{token_{2}} @, # ^ object ner type pos_1 ^ object # <-- Appends all PoS tags \in multiset(entity_{POStags}) using punct representation
#     - typed_entity_marker_pos_set_punct: @ * subject ner type + pos_1 + pos_2 * subject_{token_{1}} subject_{token_{2}} @, # ^ object ner type pos_1 ^ object # <-- Appends all PoS tags \in multiset(entity_{POStags}) using punct representation

# %%
train_file = os.path.join("./train_examples.json");
dev_file = os.path.join("./dev_examples.json");
test_file = os.path.join("./test_examples.json");

from transformers import AutoConfig, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(
    "bert-base-cased"
);

arguments = ArgumentsContainer(args, tokenizer);

processor = RETACREDProcessor(arguments, tokenizer=tokenizer);

processor.read(train_file);
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 1222.95it/s]
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom']
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom']
# ['T', '##hab', '##ane', '#']
# ['T', '##hab', '##ane', '#']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#']
# ['resigned']
# ['resigned']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned']
# ['in']
# ['in']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in']
# ['October']
# ['October']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October']
# ['last']
# ['last']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last']
# ['year']
# ['year']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year']
# ['to']
# ['to']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to']
# ['form']
# ['form']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form']
# ['the']
# ['the']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the']
# ['@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All']
# ['@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All']
# ['Ba', '##so', '##th', '##o']
# ['Ba', '##so', '##th', '##o']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o']
# ['Convention', '@']
# ['Convention', '@']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@']
# ['(']
# ['(']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(']
# ['ABC']
# ['ABC']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC']
# [')']
# [')']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')']
# [',']
# [',']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',']
# ['crossing']
# ['crossing']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing']
# ['the']
# ['the']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the']
# ['floor']
# ['floor']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor']
# ['with']
# ['with']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with']
# ['17']
# ['17']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17']
# ['members']
# ['members']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members']
# ['of']
# ['of']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of']
# ['parliament']
# ['parliament']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament']
# [',']
# [',']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',']
# ['causing']
# ['causing']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing']
# ['constitutional']
# ['constitutional']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional']
# ['monarch']
# ['monarch']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch']
# ['King']
# ['King']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King']
# ['Let', '##sie']
# ['Let', '##sie']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie']
# ['III']
# ['III']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III']
# ['to']
# ['to']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to']
# ['dissolve']
# ['dissolve']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve']
# ['parliament']
# ['parliament']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament']
# ['and']
# ['and']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and']
# ['call']
# ['call']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and', 'call']
# ['the']
# ['the']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and', 'call', 'the']
# ['snap']
# ['snap']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and', 'call', 'the', 'snap']
# ['election']
# ['election']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and', 'call', 'the', 'snap', 'election']
# ['.']
# ['.']
# sents:
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and', 'call', 'the', 'snap', 'election', '.']
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'Tom', 'T', '##hab', '##ane', '#', 'resigned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organization', ':', 'D', '##T', '+', 'N', '##NP', '*', 'All', 'Ba', '##so', '##th', '##o', 'Convention', '@', '(', 'ABC', ')', ',', 'crossing', 'the', 'floor', 'with', '17', 'members', 'of', 'parliament', ',', 'causing', 'constitutional', 'monarch', 'King', 'Let', '##sie', 'III', 'to', 'dissolve', 'parliament', 'and', 'call', 'the', 'snap', 'election', '.']
# [101, 108, 167, 1825, 131, 151, 14576, 167, 2545, 157, 17266, 6354, 108, 4603, 1107, 1357, 1314, 1214, 1106, 1532, 1103, 137, 115, 2369, 131, 141, 1942, 116, 151, 14576, 115, 1398, 18757, 7301, 1582, 1186, 5818, 137, 113, 5254, 114, 117, 4905, 1103, 1837, 1114, 1542, 1484, 1104, 6254, 117, 3989, 7950, 14390, 1624, 2421, 9819, 2684, 1106, 24907, 6254, 1105, 1840, 1103, 11152, 1728, 119, 102]
# 1
# {'input_ids': [101, 108, 167, 1825, 131, 151, 14576, 167, 2545, 157, 17266, 6354, 108, 4603, 1107, 1357, 1314, 1214, 1106, 1532, 1103, 137, 115, 2369, 131, 141, 1942, 116, 151, 14576, 115, 1398, 18757, 7301, 1582, 1186, 5818, 137, 113, 5254, 114, 117, 4905, 1103, 1837, 1114, 1542, 1484, 1104, 6254, 117, 3989, 7950, 14390, 1624, 2421, 9819, 2684, 1106, 24907, 6254, 1105, 1840, 1103, 11152, 1728, 119, 102], 'labels': 1, 'ss': 21, 'os': 1}
# ['In']
# ['In']
# sents:
# ['In']
# ['1983']
# ['1983']
# sents:
# ['In', '1983']
# [',']
# [',']
# sents:
# ['In', '1983', ',']
# ['a']
# ['a']
# sents:
# ['In', '1983', ',', 'a']
# ['year']
# ['year']
# sents:
# ['In', '1983', ',', 'a', 'year']
# ['after']
# ['after']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after']
# ['the']
# ['the']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the']
# ['rally']
# ['rally']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally']
# [',']
# [',']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',']
# ['@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@']
# ['@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@']
# ['received']
# ['received']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received']
# ['the']
# ['the']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the']
# ['so', '-', 'called']
# ['so', '-', 'called']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called']
# ['`', '`']
# ['`', '`']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`']
# ['genius']
# ['genius']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius']
# ['award']
# ['award']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award']
# ["'", "'"]
# ["'", "'"]
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'"]
# ['from']
# ['from']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from']
# ['the']
# ['the']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the']
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'John']
# ['#', '^', 'person', ':', 'N', '##NP', '^', 'John']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', ':', 'N', '##NP', '^', 'John']
# ['D', '.', '#']
# ['D', '.', '#']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', ':', 'N', '##NP', '^', 'John', 'D', '.', '#']
# ['and']
# ['and']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', ':', 'N', '##NP', '^', 'John', 'D', '.', '#', 'and']
# ['Catherine']
# ['Catherine']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', ':', 'N', '##NP', '^', 'John', 'D', '.', '#', 'and', 'Catherine']
# ['T', '.']
# ['T', '.']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', ':', 'N', '##NP', '^', 'John', 'D', '.', '#', 'and', 'Catherine', 'T', '.']
# ['MacArthur']
# ['MacArthur']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', ':', 'N', '##NP', '^', 'John', 'D', '.', '#', 'and', 'Catherine', 'T', '.', 'MacArthur']
# ['Foundation']
# ['Foundation']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', ':', 'N', '##NP', '^', 'John', 'D', '.', '#', 'and', 'Catherine', 'T', '.', 'MacArthur', 'Foundation']
# ['.']
# ['.']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', ':', 'N', '##NP', '^', 'John', 'D', '.', '#', 'and', 'Catherine', 'T', '.', 'MacArthur', 'Foundation', '.']
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'rally', ',', '@', '*', 'person', ':', 'N', '##NP', '*', 'For', '##sberg', '@', 'received', 'the', 'so', '-', 'called', '`', '`', 'genius', 'award', "'", "'", 'from', 'the', '#', '^', 'person', ':', 'N', '##NP', '^', 'John', 'D', '.', '#', 'and', 'Catherine', 'T', '.', 'MacArthur', 'Foundation', '.']
# [101, 1130, 2278, 117, 170, 1214, 1170, 1103, 11158, 117, 137, 115, 1825, 131, 151, 14576, 115, 1370, 19945, 137, 1460, 1103, 1177, 118, 1270, 169, 169, 13533, 2574, 112, 112, 1121, 1103, 108, 167, 1825, 131, 151, 14576, 167, 1287, 141, 119, 108, 1105, 6017, 157, 119, 21045, 2974, 119, 102]
# 33
# {'input_ids': [101, 1130, 2278, 117, 170, 1214, 1170, 1103, 11158, 117, 137, 115, 1825, 131, 151, 14576, 115, 1370, 19945, 137, 1460, 1103, 1177, 118, 1270, 169, 169, 13533, 2574, 112, 112, 1121, 1103, 108, 167, 1825, 131, 151, 14576, 167, 1287, 141, 119, 108, 1105, 6017, 157, 119, 21045, 2974, 119, 102], 'labels': 0, 'ss': 10, 'os': 33}
# ['This']
# ['This']
# sents:
# ['This']
# ['was']
# ['was']
# sents:
# ['This', 'was']
# ['among']
# ['among']
# sents:
# ['This', 'was', 'among']
# ['a']
# ['a']
# sents:
# ['This', 'was', 'among', 'a']
# ['batch']
# ['batch']
# sents:
# ['This', 'was', 'among', 'a', 'batch']
# ['of']
# ['of']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of']
# ['paperback']
# ['paperback']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback']
# ['#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford']
# ['#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford']
# ['World', '#']
# ['World', '#']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#']
# ["'", 's']
# ["'", 's']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's']
# ['Classics']
# ['Classics']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics']
# ['that']
# ['that']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that']
# ['I']
# ['I']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I']
# ['was']
# ['was']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was']
# ['given']
# ['given']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given']
# ['as']
# ['as']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as']
# ['a']
# ['a']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a']
# ['reward']
# ['reward']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward']
# ['for']
# ['for']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for']
# ['reading']
# ['reading']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading']
# ['and']
# ['and']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and']
# ['commenting']
# ['commenting']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting']
# ['on']
# ['on']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on']
# ['a']
# ['a']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on', 'a']
# ['manuscript']
# ['manuscript']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on', 'a', 'manuscript']
# ['for']
# ['for']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on', 'a', 'manuscript', 'for']
# ['@', '*', 'organization', ':', 'N', '##N', '*', 'O', '##UP', '@']
# ['@', '*', 'organization', ':', 'N', '##N', '*', 'O', '##UP', '@']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on', 'a', 'manuscript', 'for', '@', '*', 'organization', ':', 'N', '##N', '*', 'O', '##UP', '@']
# ['.']
# ['.']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on', 'a', 'manuscript', 'for', '@', '*', 'organization', ':', 'N', '##N', '*', 'O', '##UP', '@', '.']
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paperback', '#', '^', 'organization', ':', 'N', '##NP', '^', 'Oxford', 'World', '#', "'", 's', 'Classics', 'that', 'I', 'was', 'given', 'as', 'a', 'reward', 'for', 'reading', 'and', 'commenting', 'on', 'a', 'manuscript', 'for', '@', '*', 'organization', ':', 'N', '##N', '*', 'O', '##UP', '@', '.']
# [101, 1188, 1108, 1621, 170, 15817, 1104, 16885, 108, 167, 2369, 131, 151, 14576, 167, 3500, 1291, 108, 112, 188, 14387, 1115, 146, 1108, 1549, 1112, 170, 10703, 1111, 3455, 1105, 18912, 1113, 170, 8323, 1111, 137, 115, 2369, 131, 151, 2249, 115, 152, 18124, 137, 119, 102]
# 8
# {'input_ids': [101, 1188, 1108, 1621, 170, 15817, 1104, 16885, 108, 167, 2369, 131, 151, 14576, 167, 3500, 1291, 108, 112, 188, 14387, 1115, 146, 1108, 1549, 1112, 170, 10703, 1111, 3455, 1105, 18912, 1113, 170, 8323, 1111, 137, 115, 2369, 131, 151, 2249, 115, 152, 18124, 137, 119, 102], 'labels': 0, 'ss': 36, 'os': 8}

# %%
input_formats = [
  "entity_mask",
  "entity_marker",
  "entity_marker_punct",
  "typed_entity_marker",
  "typed_entity_marker_punct",
  "typed_entity_marker_pos",
  "typed_entity_marker_pos_seq",
  "typed_entity_marker_pos_set",
  "typed_entity_marker_pos_punct",
  "typed_entity_marker_pos_seq_punct",
  "typed_entity_marker_pos_set_punct"
];

# see the process for all possible types of markers
for scheduled_input in input_formats:
  arguments.set_input_format(scheduled_input);
  newProcessor = RETACREDProcessor(arguments, tokenizer=tokenizer);
  print(f"\n\n\n############# {scheduled_input} ###############\n\n\n")
  dev_features = processor.read(train_file)
# Out:
# ############# entity_mask ###############
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[18], line 20
#      18 newProcessor = RETACREDProcessor(arguments, tokenizer=tokenizer);
#      19 print(f"\n\n\n############# {scheduled_input} ###############\n\n\n")
# ---> 20 dev_features = processor.read(dev_file[0])
#
# Cell In[5], line 307, in RETACREDProcessor.read(self, file_in)
#     305 def read(self, file_in):
#     306     features = []
# --> 307     with open(file_in, "r") as fh:
#     308         data = json.load(fh)
#     310     for d in tqdm(data):
#
# File ~/anaconda3/envs/ml-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# IsADirectoryError: [Errno 21] Is a directory: '.'

# %% [markdown]
# ### Observations & Considerations
#
# Having ran a few experiments at this point (and, it takes a while to get the fine-tuning done over three distinct datasets, for multiple models), for a single PoS Tag, any performance change is negliable. Plus, the models (BERT, SpanBERT, RoBERTa) should be extracting the syntactic features themselves anyway, so I'm not convinced that throwing an extra PoS tag in is neccesarily going to help a huge deal. Esp. since if you take a look at experimental notebook 01_exploratory_notebook.ipynb, you can see that the distribution of PoS tags is **HIGHLY SKEWED** in the direction of NNPs; so, I guess this approach was perhaps doomed to fail for the get go.
#
# Still. I think there may be some places where we can get some performance gain. Namely, two areas.
#
# 1. The older style of typed entity markers may see some performance gain when including the set of PoS Tags, **maybe**.
# 2. The stanford_deprel tags are much more distributed (though still fairly skewed in favour of `compound` but nowhere near as bad as the PoS tags)
#
# As such, whilst the fine-tuning is going on to produce the results for the other experiments, I'm just going to implement some logic to prep some additional exploratory experiments.
#
# I also have a suspicion that perhaps guiding the model towards the syntax explicitly may be helpful for entities described through a larger number of tokens, where there is some variation in their sentances parsed dependency tree.
#
# It would be interesting to sample the datasets and extract a uniform distribution of samples with tokenised entity size from n to n + 6; and then see how the performance changes w.r.t having these additional features explicitly encoded into the representation during fine-tuning. I'd be curious to see if there is any performance difference at all; it feels as though perhaps the model ought to learn faster, but I am still thinking this all through... It's not super easy to get a good intuition for this stuff.

# %%
from tqdm import tqdm
import ujson as json


def convert_token(token):
    """ Convert PTB tokens to normal tokens """
    if (token.lower() == '-lrb-'):
        return '('
    elif (token.lower() == '-rrb-'):
        return ')'
    elif (token.lower() == '-lsb-'):
        return '['
    elif (token.lower() == '-rsb-'):
        return ']'
    elif (token.lower() == '-lcb-'):
        return '{'
    elif (token.lower() == '-rcb-'):
        return '}'
    return token


class Processor:
    def __init__(self, args, tokenizer):
        super().__init__()
        self.args = args
        self.tokenizer = tokenizer
        self.new_tokens = []
        if self.args.input_format == 'entity_marker':
            self.new_tokens = ['[E1]', '[/E1]', '[E2]', '[/E2]']
        self.tokenizer.add_tokens(self.new_tokens)
        # changes: added 'typed_entity_marker_pos', 'typed_entity_marker_pos_punct' to the list of valid formats
        if self.args.input_format not in ('entity_mask', 'entity_marker', 'entity_marker_punct', 'typed_entity_marker', 'typed_entity_marker_punct', 'typed_entity_marker_pos', 'typed_entity_marker_pos_seq', 'typed_entity_marker_pos_set', 'typed_entity_marker_pos_punct', 'typed_entity_marker_pos_seq_punct', 'typed_entity_marker_pos_set_punct', 'typed_entity_marker_deprel_set_punct'):
            raise Exception("Invalid input format!")

    def tokenize(self, tokens, subj_type, obj_type, ss, se, os, oe, pos_tags=None, deprel_tags=None):
        if not pos_tags or not deprel_tags:
            raise Exception("No pos/deprel tags supplied.");
        """
        Implement the following input formats:
            - entity_mask: [SUBJ-NER], [OBJ-NER].
            - entity_marker: [E1] subject [/E1], [E2] object [/E2].
            - entity_marker_punct: @ subject @, # object #.
            - typed_entity_marker: [SUBJ-NER] subject [/SUBJ-NER], [OBJ-NER] obj [/OBJ-NER]
            - typed_entity_marker_punct: @ * subject ner type * subject @, # ^ object ner type ^ object #
            - typed_entity_marker_pos: [SUBJ-NER*POS1] subject [/SUBJ-NER*POS1], [OBJ-NER*POS1] obj [/OBJ-NER*POS1] <-- Appends the first PoS tag to the marker
            - typed_entity_marker_pos_seq: [SUBJ-NER*POS1+POS2] subject [/SUBJ-NER*POS1+POS2], [OBJ-NER*POS1+POS2] obj [/OBJ-NER*POS1+POS2] <-- Appends all PoS tags \in multiset(entity_{POStags})
            - typed_entity_marker_pos_set: [SUBJ-NER*UNIQUEPOS1+UNIQUEPOS2] subject [/SUBJ-NER*UNIQUEPOS1+UNIQUEPOS2], [OBJ-NER*UNIQUEPOS1+UNIQUEPOS2] obj [/OBJ-NER*UNIQUEPOS1+UNIQUEPOS2] <-- Appends all PoS tags \in set(entity_{POStags})
            - typed_entity_marker_pos_punct: @ * subject ner type + pos tag * subject @, # ^ object ner type pos tag ^ object # <-- Appends first PoS tag using punct representation
            - typed_entity_marker_pos_seq_punct: @ * subject ner type + pos_1 + pos_2 * subject_{token_{1}} subject_{token_{2}} @, # ^ object ner type pos_1 ^ object # <-- Appends all PoS tags \in multiset(entity_{POStags}) using punct representation
            - typed_entity_marker_pos_set_punct: @ * subject ner type + pos_1 + pos_2 * subject_{token_{1}} subject_{token_{2}} @, # ^ object ner type pos_1 ^ object # <-- Appends all PoS tags \in multiset(entity_{POStags}) using punct representation
        """
        
        sents = []
        input_format = self.args.input_format
        
        if input_format == 'entity_mask':
            subj_type = '[SUBJ-{}]'.format(subj_type)
            obj_type = '[OBJ-{}]'.format(obj_type)
            for token in (subj_type, obj_type):
                if token not in self.new_tokens:
                    self.new_tokens.append(token)
                    self.tokenizer.add_tokens([token])
        
        elif input_format == 'typed_entity_marker':
            subj_start = '[SUBJ-{}]'.format(subj_type)
            subj_end = '[/SUBJ-{}]'.format(subj_type)
            obj_start = '[OBJ-{}]'.format(obj_type)
            obj_end = '[/OBJ-{}]'.format(obj_type)
            for token in (subj_start, subj_end, obj_start, obj_end):
                if token not in self.new_tokens:
                    self.new_tokens.append(token)
                    self.tokenizer.add_tokens([token])
        
        # approach #1: producing a subj/obj strart & subj/obj end tag by appending the PoS tag @ ss, se, os & oe \in multiset(entity_{POStags}) to 'subject/object' & entity-type:
        # e.g. [SUBJ-PERSON-NPP] Alice Dellal [/SUBJ-PERSON-NPP]
        elif input_format == 'typed_entity_marker_pos':
            # construct subject tags
            subj_start = '[SUBJ-{}*{}]'.format(subj_type, pos_tags[ss]);
            subj_end = '[/SUBJ-{}*{}]'.format(subj_type, pos_tags[se]);
            # & object tags
            obj_start = '[OBJ-{}*{}]'.format(obj_type, pos_tags[os]);
            obj_end = '[/OBJ-{}*{}]'.format(obj_type, pos_tags[oe]);
            # if these tokens are considered unseen new tokens, add them to the set of new tokens
            for token in (subj_start, subj_end, obj_start, obj_end):
                if token not in self.new_tokens:
                    self.new_tokens.append(token);
                    self.tokenizer.add_tokens([token]);
        
        # approach #2: producing a subj start & subj end tag by concat'ing the subject/object, entity-type & sequenced PoS tags together
        # if the entity length is > 1, then produce [SUBJ-TYPE*POS1+POS2] subj_token_1 subj_token_2 [/SUBJ-TYPE*POS1+POS2] & same for the obj
        elif input_format == 'typed_entity_marker_pos_seq':
            # grabbing the PoS between the subject start & subject end 
            subj_pos_tags = pos_tags[ss : se + 1];
            # constructing a PoS string to represent the sequence of tags
            subj_pos_string = "+".join(subj_pos_tags);
            # building the subj opening & closing tag
            subj_start = '[SUBJ-{}*{}]'.format(subj_type, subj_pos_string);
            subj_end = '[/SUBJ-{}*{}]'.format(subj_type, subj_pos_string);
            # same again for object start & end tag
            obj_pos_tags = pos_tags[os : oe + 1];
            obj_pos_string = "+".join(obj_pos_tags);
            obj_start = '[OBJ-{}*{}]'.format(obj_type, obj_pos_string);
            obj_end = '[/OBJ-{}*{}]'.format(obj_type, obj_pos_string);
            # if these tokens are considered unseen new tokens, add them to the set of new tokens
            for token in (subj_start, subj_end, obj_start, obj_end):
                if token not in self.new_tokens:
                    self.new_tokens.append(token);
                    self.tokenizer.add_tokens([token]);

        # approach #3: similar to approach #2, but simply take the set of PoS tags
        elif input_format == 'typed_entity_marker_pos_set':
            # rather than use set(), we're going to retain some degree of order
            subj_pos_tags = list(dict.fromkeys(pos_tags[ss : se + 1]));
            subj_pos_string = "+".join(subj_pos_tags);
            subj_start = '[SUBJ-{}*{}]'.format(subj_type, subj_pos_string);
            subj_end = '[/SUBJ-{}*{}]'.format(subj_type, subj_pos_string);
            # same for obj
            obj_pos_tags = list(dict.fromkeys(pos_tags[os : oe + 1]));
            obj_pos_string = "+".join(obj_pos_tags);
            obj_start = '[OBJ-{}*{}]'.format(obj_type, obj_pos_string);
            obj_end = '[/OBJ-{}*{}]'.format(obj_type, obj_pos_string);
            for token in (subj_start, subj_end, obj_start, obj_end):
                if token not in self.new_tokens:
                    self.new_tokens.append(token);
                    self.tokenizer.add_tokens([token]);

        # original adaptation from: https://arxiv.org/pdf/2102.01373v4
        elif input_format == 'typed_entity_marker_punct':
            subj_type = self.tokenizer.tokenize(subj_type.replace("_", " ").lower())
            obj_type = self.tokenizer.tokenize(obj_type.replace("_", " ").lower())

        # approach #4: adding a single PoS tag 
        elif input_format == 'typed_entity_marker_pos_punct':
            subj_first_pos = pos_tags[ss];
            obj_first_pos = pos_tags[os];
            subj_type = subj_type.replace("_", " ").lower()
            subj_type = self.tokenizer.tokenize(subj_type + "+" + subj_first_pos)
            obj_type = obj_type.replace("_", " ").lower()
            obj_type = self.tokenizer.tokenize(obj_type + "+" + obj_first_pos)

        # approach #5:
        elif input_format == 'typed_entity_marker_pos_seq_punct':
            # see approach #2
            subj_pos_tags = pos_tags[ss : se + 1];
            subj_pos_string = "+".join(subj_pos_tags);
            obj_pos_tags = pos_tags[os : oe + 1];
            obj_pos_string = "+".join(obj_pos_tags);
            # reuse part of originally adapted approach
            subj_type = subj_type.replace("_", " ").lower();
            obj_type = obj_type.replace("_", " ").lower();
            # concatenate PoS tags
            subj_type = self.tokenizer.tokenize(subj_type) + [':'] + self.tokenizer.tokenize(subj_pos_string);
            obj_type = self.tokenizer.tokenize(obj_type) + [':'] + self.tokenizer.tokenize(obj_pos_string);

        # approach #6:
        elif input_format == 'typed_entity_marker_pos_set_punct':
            # see approach #3
            subj_pos_tags = list(dict.fromkeys(pos_tags[ss : se + 1]));
            subj_pos_string = "+".join(subj_pos_tags);
            obj_pos_tags = list(dict.fromkeys(pos_tags[os : oe + 1]));
            obj_pos_string = "+".join(obj_pos_tags);
            # reuse part of originally adapted approach
            subj_type = subj_type.replace("_", " ").lower();
            obj_type = obj_type.replace("_", " ").lower();
            # concatenate PoS tags
            subj_type = self.tokenizer.tokenize(subj_type) + [":"] + self.tokenizer.tokenize(subj_pos_string);
            obj_type = self.tokenizer.tokenize(obj_type) + [":"] + self.tokenizer.tokenize(obj_pos_string);

        # approach #7
        elif input_format == 'typed_entity_marker_deprel_set_punct':
            # see approach #6
            subj_deprel_tags = list(dict.fromkeys(deprel_tags[ss : se]));
            subj_deprel_string = " ".join(subj_deprel_tags);
            obj_deprel_tags = list(dict.fromkeys(deprel_tags[os : oe]));
            obj_deprel_string = " ".join(obj_deprel_tags);
            inj_subj_type = subj_type.replace("_", " ").lower();
            inj_obj_type = obj_type.replace("_", " ").lower();
            subj_type = self.tokenizer.tokenize(inj_subj_type) + self.tokenizer.tokenize(subj_deprel_string);
            obj_type = self.tokenizer.tokenize(inj_obj_type) + self.tokenizer.tokenize(obj_deprel_string);
        


        for i_t, token in enumerate(tokens):
            tokens_wordpiece = self.tokenizer.tokenize(token)

            if input_format == 'entity_mask':
                if ss <= i_t <= se or os <= i_t <= oe:
                    tokens_wordpiece = []
                    if i_t == ss:
                        new_ss = len(sents)
                        tokens_wordpiece = [subj_type]
                    if i_t == os:
                        new_os = len(sents)
                        tokens_wordpiece = [obj_type]

            elif input_format == 'entity_marker':
                if i_t == ss:
                    new_ss = len(sents)
                    tokens_wordpiece = ['[E1]'] + tokens_wordpiece
                if i_t == se:
                    tokens_wordpiece = tokens_wordpiece + ['[/E1]']
                if i_t == os:
                    new_os = len(sents)
                    tokens_wordpiece = ['[E2]'] + tokens_wordpiece
                if i_t == oe:
                    tokens_wordpiece = tokens_wordpiece + ['[/E2]']

            elif input_format == 'entity_marker_punct':
                if i_t == ss:
                    new_ss = len(sents)
                    tokens_wordpiece = ['@'] + tokens_wordpiece
                if i_t == se:
                    tokens_wordpiece = tokens_wordpiece + ['@']
                if i_t == os:
                    new_os = len(sents)
                    tokens_wordpiece = ['#'] + tokens_wordpiece
                if i_t == oe:
                    tokens_wordpiece = tokens_wordpiece + ['#']

            elif input_format == 'typed_entity_marker' or input_format == 'typed_entity_marker_pos' or input_format == 'typed_entity_marker_pos_seq' or input_format == 'typed_entity_marker_pos_set':
                if i_t == ss:
                    new_ss = len(sents)
                    tokens_wordpiece = [subj_start] + tokens_wordpiece
                if i_t == se:
                    tokens_wordpiece = tokens_wordpiece + [subj_end]
                if i_t == os:
                    new_os = len(sents)
                    tokens_wordpiece = [obj_start] + tokens_wordpiece
                if i_t == oe:
                    tokens_wordpiece = tokens_wordpiece + [obj_end]

            elif input_format == 'typed_entity_marker_punct' or input_format == 'typed_entity_marker_pos_punct' or input_format == 'typed_entity_marker_pos_seq_punct' or input_format == 'typed_entity_marker_pos_set_punct' or input_format == 'typed_entity_marker_deprel_set_punct':
                if i_t == ss:
                    new_ss = len(sents)
                    tokens_wordpiece = ['@'] + ['*'] + subj_type + ['*'] + tokens_wordpiece
                if i_t == se:
                    tokens_wordpiece = tokens_wordpiece + ['@']
                if i_t == os:
                    new_os = len(sents)
                    tokens_wordpiece = ["#"] + ['^'] + obj_type + ['^'] + tokens_wordpiece
                if i_t == oe:
                    tokens_wordpiece = tokens_wordpiece + ["#"]

                print(tokens_wordpiece);

            print(tokens_wordpiece);
            sents.extend(tokens_wordpiece)
            print("sents: ");
            print(sents);
        sents = sents[:self.args.max_seq_length - 2]
        print(sents);
        input_ids = self.tokenizer.convert_tokens_to_ids(sents)
        input_ids = self.tokenizer.build_inputs_with_special_tokens(input_ids)
        print(input_ids);
        print(new_ss + 1);
        print(new_os + 1);
        return input_ids, new_ss + 1, new_os + 1


class TACREDProcessor(Processor):
    def __init__(self, args, tokenizer):
        super().__init__(args, tokenizer)
        self.LABEL_TO_ID = {'no_relation': 0, 'per:title': 1, 'org:top_members/employees': 2, 'per:employee_of': 3, 'org:alternate_names': 4, 'org:country_of_headquarters': 5, 'per:countries_of_residence': 6, 'org:city_of_headquarters': 7, 'per:cities_of_residence': 8, 'per:age': 9, 'per:stateorprovinces_of_residence': 10, 'per:origin': 11, 'org:subsidiaries': 12, 'org:parents': 13, 'per:spouse': 14, 'org:stateorprovince_of_headquarters': 15, 'per:children': 16, 'per:other_family': 17, 'per:alternate_names': 18, 'org:members': 19, 'per:siblings': 20, 'per:schools_attended': 21, 'per:parents': 22, 'per:date_of_death': 23, 'org:member_of': 24, 'org:founded_by': 25, 'org:website': 26, 'per:cause_of_death': 27, 'org:political/religious_affiliation': 28, 'org:founded': 29, 'per:city_of_death': 30, 'org:shareholders': 31, 'org:number_of_employees/members': 32, 'per:date_of_birth': 33, 'per:city_of_birth': 34, 'per:charges': 35, 'per:stateorprovince_of_death': 36, 'per:religion': 37, 'per:stateorprovince_of_birth': 38, 'per:country_of_birth': 39, 'org:dissolved': 40, 'per:country_of_death': 41}

    def read(self, file_in):
        features = []
        with open(file_in, "r") as fh:
            data = json.load(fh)

        for d in tqdm(data):
            ss, se = d['subj_start'], d['subj_end']
            os, oe = d['obj_start'], d['obj_end']

            tokens = d['token']
            tokens = [convert_token(token) for token in tokens]

            # modified tokenize to also accept the PoS tags, it's important to understand that whilst the subj_type & obj_type are a single token, i.e. 'person' or 'organisation'
            # the PoS tags could be a list of length > 1. This may cause some issues when representing the the start-subject, end-subject, start-object & end-object as
            # their own distinct tags (i.e. [SUB-PERSON-NNP-NNP-NNP] jon anthony dil [/SUB-PERSON-NNP-NNP-NNP]) due to the creeping tag length
            # Further: using an alternative representation may shorten the observable context, i.e. '@ * person : nnp + nnp + nnp * jon anthony dil @'
            # TODO: go back and read through the papers again on the various models we're using here to understand the implications of these various changes in more depth
            input_ids, new_ss, new_os = self.tokenize(tokens, d['subj_type'], d['obj_type'], ss, se, os, oe, pos_tags=d['stanford_pos'], deprel_tags=d['stanford_deprel']) # <-- CHANGES # pos_tags=d['stanford_pos']
            rel = self.LABEL_TO_ID[d['relation']]

            feature = {
                'input_ids': input_ids,
                'labels': rel,
                'ss': new_ss,
                'os': new_os,
            }

            features.append(feature)
        return features


class RETACREDProcessor(Processor):
    def __init__(self, args, tokenizer):
        super().__init__(args, tokenizer)
        self.LABEL_TO_ID = {'no_relation': 0, 'org:founded_by': 1, 'per:identity': 2, 'org:alternate_names': 3, 'per:children': 4, 'per:origin': 5, 'per:countries_of_residence': 6, 'per:employee_of': 7, 'per:title': 8, 'org:city_of_branch': 9, 'per:religion': 10, 'per:age': 11, 'per:date_of_death': 12, 'org:website': 13, 'per:stateorprovinces_of_residence': 14, 'org:top_members/employees': 15, 'org:number_of_employees/members': 16, 'org:members': 17, 'org:country_of_branch': 18, 'per:spouse': 19, 'org:stateorprovince_of_branch': 20, 'org:political/religious_affiliation': 21, 'org:member_of': 22, 'per:siblings': 23, 'per:stateorprovince_of_birth': 24, 'org:dissolved': 25, 'per:other_family': 26, 'org:shareholders': 27, 'per:parents': 28, 'per:charges': 29, 'per:schools_attended': 30, 'per:cause_of_death': 31, 'per:city_of_death': 32, 'per:stateorprovince_of_death': 33, 'org:founded': 34, 'per:country_of_death': 35, 'per:country_of_birth': 36, 'per:date_of_birth': 37, 'per:cities_of_residence': 38, 'per:city_of_birth': 39}

    def read(self, file_in):
        features = []
        with open(file_in, "r") as fh:
            data = json.load(fh)

        for d in tqdm(data):
            ss, se = d['subj_start'], d['subj_end']
            os, oe = d['obj_start'], d['obj_end']

            tokens = d['token']
            tokens = [convert_token(token) for token in tokens]

            # modified tokenize to also accept the PoS tags
            input_ids, new_ss, new_os = self.tokenize(tokens, d['subj_type'], d['obj_type'], ss, se, os, oe, pos_tags=d['stanford_pos'], deprel_tags=d['stanford_deprel']) # <-- CHANGES # pos_tags=d['stanford_pos']
            rel = self.LABEL_TO_ID[d['relation']]

            feature = {
                'input_ids': input_ids,
                'labels': rel,
                'ss': new_ss,
                'os': new_os,
            }

            print(feature);

            features.append(feature)
        return features
# Out:
# <>:38: SyntaxWarning: invalid escape sequence '\i'
# <>:38: SyntaxWarning: invalid escape sequence '\i'
# /tmp/ipykernel_329252/3167388691.py:38: SyntaxWarning: invalid escape sequence '\i'
#   """

# %%
train_file = os.path.join("./train_examples.json");
dev_file = os.path.join("./dev_examples.json");
test_file = os.path.join("./test_examples.json");

from transformers import AutoConfig, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(
    "roberta-large"
);

class someArgs:
  max_seq_length = 128;
  input_format = "typed_entity_marker_deprel_set_punct";

  def __init__(self, args, tokenizer):
    super().__init__();
    self.args = args;
    self.tokenizer = tokenizer;
    self.input_format = "typed_entity_marker_deprel_set_punct";
    self.max_seq_length: 128;

args = {
  'input_format': "typed_entity_marker_deprel_set_punct",
  'max_seq_length': 128
};

arguments = someArgs(args, tokenizer);

processor = RETACREDProcessor(arguments, tokenizer=tokenizer);

processor.read(train_file);
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 1149.44it/s]
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom']
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom']
# ['Th', 'ab', 'ane', '#']
# ['Th', 'ab', 'ane', '#']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#']
# ['res', 'igned']
# ['res', 'igned']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned']
# ['in']
# ['in']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in']
# ['October']
# ['October']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October']
# ['last']
# ['last']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last']
# ['year']
# ['year']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year']
# ['to']
# ['to']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to']
# ['form']
# ['form']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form']
# ['the']
# ['the']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the']
# ['@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All']
# ['@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All']
# ['Bas', 'oth', 'o']
# ['Bas', 'oth', 'o']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o']
# ['Con', 'vention', '@']
# ['Con', 'vention', '@']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@']
# ['(']
# ['(']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(']
# ['ABC']
# ['ABC']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC']
# [')']
# [')']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')']
# [',']
# [',']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',']
# ['cross', 'ing']
# ['cross', 'ing']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing']
# ['the']
# ['the']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the']
# ['floor']
# ['floor']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor']
# ['with']
# ['with']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with']
# ['17']
# ['17']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17']
# ['members']
# ['members']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members']
# ['of']
# ['of']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of']
# ['par', 'liament']
# ['par', 'liament']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament']
# [',']
# [',']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',']
# ['ca', 'using']
# ['ca', 'using']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using']
# ['constitutional']
# ['constitutional']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional']
# ['mon', 'arch']
# ['mon', 'arch']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch']
# ['King']
# ['King']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King']
# ['L', 'ets', 'ie']
# ['L', 'ets', 'ie']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King', 'L', 'ets', 'ie']
# ['III']
# ['III']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King', 'L', 'ets', 'ie', 'III']
# ['to']
# ['to']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King', 'L', 'ets', 'ie', 'III', 'to']
# ['d', 'iss', 'olve']
# ['d', 'iss', 'olve']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King', 'L', 'ets', 'ie', 'III', 'to', 'd', 'iss', 'olve']
# ['par', 'liament']
# ['par', 'liament']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King', 'L', 'ets', 'ie', 'III', 'to', 'd', 'iss', 'olve', 'par', 'liament']
# ['and']
# ['and']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King', 'L', 'ets', 'ie', 'III', 'to', 'd', 'iss', 'olve', 'par', 'liament', 'and']
# ['call']
# ['call']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King', 'L', 'ets', 'ie', 'III', 'to', 'd', 'iss', 'olve', 'par', 'liament', 'and', 'call']
# ['the']
# ['the']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King', 'L', 'ets', 'ie', 'III', 'to', 'd', 'iss', 'olve', 'par', 'liament', 'and', 'call', 'the']
# ['snap']
# ['snap']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King', 'L', 'ets', 'ie', 'III', 'to', 'd', 'iss', 'olve', 'par', 'liament', 'and', 'call', 'the', 'snap']
# ['election']
# ['election']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King', 'L', 'ets', 'ie', 'III', 'to', 'd', 'iss', 'olve', 'par', 'liament', 'and', 'call', 'the', 'snap', 'election']
# ['.']
# ['.']
# sents:
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King', 'L', 'ets', 'ie', 'III', 'to', 'd', 'iss', 'olve', 'par', 'liament', 'and', 'call', 'the', 'snap', 'election', '.']
# ['#', '^', 'person', 'comp', 'ound', '^', 'Tom', 'Th', 'ab', 'ane', '#', 'res', 'igned', 'in', 'October', 'last', 'year', 'to', 'form', 'the', '@', '*', 'organ', 'ization', 'comp', 'ound', '*', 'All', 'Bas', 'oth', 'o', 'Con', 'vention', '@', '(', 'ABC', ')', ',', 'cross', 'ing', 'the', 'floor', 'with', '17', 'members', 'of', 'par', 'liament', ',', 'ca', 'using', 'constitutional', 'mon', 'arch', 'King', 'L', 'ets', 'ie', 'III', 'to', 'd', 'iss', 'olve', 'par', 'liament', 'and', 'call', 'the', 'snap', 'election', '.']
# [0, 10431, 35227, 5970, 11828, 9834, 35227, 15691, 11329, 873, 1728, 10431, 1535, 9044, 179, 20144, 13751, 180, 560, 3899, 627, 1039, 3226, 17247, 1938, 11828, 9834, 3226, 3684, 40258, 6157, 139, 9157, 20874, 1039, 1640, 18929, 43, 6, 15329, 154, 627, 19198, 5632, 1360, 23742, 1116, 5489, 37078, 6, 3245, 10928, 41899, 5806, 13161, 21644, 574, 2580, 324, 24457, 560, 417, 3006, 18224, 5489, 37078, 463, 16395, 627, 43189, 6414, 4, 2]
# 21
# 1
# {'input_ids': [0, 10431, 35227, 5970, 11828, 9834, 35227, 15691, 11329, 873, 1728, 10431, 1535, 9044, 179, 20144, 13751, 180, 560, 3899, 627, 1039, 3226, 17247, 1938, 11828, 9834, 3226, 3684, 40258, 6157, 139, 9157, 20874, 1039, 1640, 18929, 43, 6, 15329, 154, 627, 19198, 5632, 1360, 23742, 1116, 5489, 37078, 6, 3245, 10928, 41899, 5806, 13161, 21644, 574, 2580, 324, 24457, 560, 417, 3006, 18224, 5489, 37078, 463, 16395, 627, 43189, 6414, 4, 2], 'labels': 1, 'ss': 21, 'os': 1}
# ['In']
# ['In']
# sents:
# ['In']
# ['1983']
# ['1983']
# sents:
# ['In', '1983']
# [',']
# [',']
# sents:
# ['In', '1983', ',']
# ['a']
# ['a']
# sents:
# ['In', '1983', ',', 'a']
# ['year']
# ['year']
# sents:
# ['In', '1983', ',', 'a', 'year']
# ['after']
# ['after']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after']
# ['the']
# ['the']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the']
# ['r', 'ally']
# ['r', 'ally']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally']
# [',']
# [',']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',']
# ['@', '*', 'person', '*', 'F', 'ors', 'berg', '@']
# ['@', '*', 'person', '*', 'F', 'ors', 'berg', '@']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@']
# ['received']
# ['received']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received']
# ['the']
# ['the']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the']
# ['so', '-', 'called']
# ['so', '-', 'called']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called']
# ['``']
# ['``']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``']
# ['gen', 'ius']
# ['gen', 'ius']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius']
# ['aw', 'ard']
# ['aw', 'ard']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard']
# ["''"]
# ["''"]
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard', "''"]
# ['from']
# ['from']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard', "''", 'from']
# ['the']
# ['the']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard', "''", 'from', 'the']
# ['#', '^', 'person', 'comp', 'ound', '^', 'John']
# ['#', '^', 'person', 'comp', 'ound', '^', 'John']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard', "''", 'from', 'the', '#', '^', 'person', 'comp', 'ound', '^', 'John']
# ['D', '.', '#']
# ['D', '.', '#']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard', "''", 'from', 'the', '#', '^', 'person', 'comp', 'ound', '^', 'John', 'D', '.', '#']
# ['and']
# ['and']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard', "''", 'from', 'the', '#', '^', 'person', 'comp', 'ound', '^', 'John', 'D', '.', '#', 'and']
# ['C', 'atherine']
# ['C', 'atherine']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard', "''", 'from', 'the', '#', '^', 'person', 'comp', 'ound', '^', 'John', 'D', '.', '#', 'and', 'C', 'atherine']
# ['T', '.']
# ['T', '.']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard', "''", 'from', 'the', '#', '^', 'person', 'comp', 'ound', '^', 'John', 'D', '.', '#', 'and', 'C', 'atherine', 'T', '.']
# ['Mac', 'Arthur']
# ['Mac', 'Arthur']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard', "''", 'from', 'the', '#', '^', 'person', 'comp', 'ound', '^', 'John', 'D', '.', '#', 'and', 'C', 'atherine', 'T', '.', 'Mac', 'Arthur']
# ['Found', 'ation']
# ['Found', 'ation']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard', "''", 'from', 'the', '#', '^', 'person', 'comp', 'ound', '^', 'John', 'D', '.', '#', 'and', 'C', 'atherine', 'T', '.', 'Mac', 'Arthur', 'Found', 'ation']
# ['.']
# ['.']
# sents:
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard', "''", 'from', 'the', '#', '^', 'person', 'comp', 'ound', '^', 'John', 'D', '.', '#', 'and', 'C', 'atherine', 'T', '.', 'Mac', 'Arthur', 'Found', 'ation', '.']
# ['In', '1983', ',', 'a', 'year', 'after', 'the', 'r', 'ally', ',', '@', '*', 'person', '*', 'F', 'ors', 'berg', '@', 'received', 'the', 'so', '-', 'called', '``', 'gen', 'ius', 'aw', 'ard', "''", 'from', 'the', '#', '^', 'person', 'comp', 'ound', '^', 'John', 'D', '.', '#', 'and', 'C', 'atherine', 'T', '.', 'Mac', 'Arthur', 'Found', 'ation', '.']
# [0, 1121, 43887, 6, 102, 180, 10669, 627, 338, 2368, 6, 1039, 3226, 5970, 3226, 597, 994, 2865, 1039, 33979, 627, 2527, 12, 4155, 49519, 4138, 6125, 1584, 1120, 17809, 7761, 627, 10431, 35227, 5970, 11828, 9834, 35227, 10567, 495, 4, 10431, 463, 347, 38687, 565, 4, 17049, 28678, 29991, 1258, 4, 2]
# 11
# 32
# {'input_ids': [0, 1121, 43887, 6, 102, 180, 10669, 627, 338, 2368, 6, 1039, 3226, 5970, 3226, 597, 994, 2865, 1039, 33979, 627, 2527, 12, 4155, 49519, 4138, 6125, 1584, 1120, 17809, 7761, 627, 10431, 35227, 5970, 11828, 9834, 35227, 10567, 495, 4, 10431, 463, 347, 38687, 565, 4, 17049, 28678, 29991, 1258, 4, 2], 'labels': 0, 'ss': 11, 'os': 32}
# ['This']
# ['This']
# sents:
# ['This']
# ['was']
# ['was']
# sents:
# ['This', 'was']
# ['among']
# ['among']
# sents:
# ['This', 'was', 'among']
# ['a']
# ['a']
# sents:
# ['This', 'was', 'among', 'a']
# ['batch']
# ['batch']
# sents:
# ['This', 'was', 'among', 'a', 'batch']
# ['of']
# ['of']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of']
# ['paper', 'back']
# ['paper', 'back']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back']
# ['#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford']
# ['#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford']
# ['World', '#']
# ['World', '#']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#']
# ["'s"]
# ["'s"]
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s"]
# ['Class', 'ics']
# ['Class', 'ics']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics']
# ['that']
# ['that']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that']
# ['I']
# ['I']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I']
# ['was']
# ['was']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was']
# ['given']
# ['given']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given']
# ['as']
# ['as']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as']
# ['a']
# ['a']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a']
# ['re', 'ward']
# ['re', 'ward']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a', 're', 'ward']
# ['for']
# ['for']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a', 're', 'ward', 'for']
# ['reading']
# ['reading']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a', 're', 'ward', 'for', 'reading']
# ['and']
# ['and']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a', 're', 'ward', 'for', 'reading', 'and']
# ['comment', 'ing']
# ['comment', 'ing']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a', 're', 'ward', 'for', 'reading', 'and', 'comment', 'ing']
# ['on']
# ['on']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a', 're', 'ward', 'for', 'reading', 'and', 'comment', 'ing', 'on']
# ['a']
# ['a']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a', 're', 'ward', 'for', 'reading', 'and', 'comment', 'ing', 'on', 'a']
# ['man', 'uscript']
# ['man', 'uscript']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a', 're', 'ward', 'for', 'reading', 'and', 'comment', 'ing', 'on', 'a', 'man', 'uscript']
# ['for']
# ['for']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a', 're', 'ward', 'for', 'reading', 'and', 'comment', 'ing', 'on', 'a', 'man', 'uscript', 'for']
# ['@', '*', 'organ', 'ization', '*', 'OUP', '@']
# ['@', '*', 'organ', 'ization', '*', 'OUP', '@']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a', 're', 'ward', 'for', 'reading', 'and', 'comment', 'ing', 'on', 'a', 'man', 'uscript', 'for', '@', '*', 'organ', 'ization', '*', 'OUP', '@']
# ['.']
# ['.']
# sents:
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a', 're', 'ward', 'for', 'reading', 'and', 'comment', 'ing', 'on', 'a', 'man', 'uscript', 'for', '@', '*', 'organ', 'ization', '*', 'OUP', '@', '.']
# ['This', 'was', 'among', 'a', 'batch', 'of', 'paper', 'back', '#', '^', 'organ', 'ization', 'comp', 'ound', '^', 'Ox', 'ford', 'World', '#', "'s", 'Class', 'ics', 'that', 'I', 'was', 'given', 'as', 'a', 're', 'ward', 'for', 'reading', 'and', 'comment', 'ing', 'on', 'a', 'man', 'uscript', 'for', '@', '*', 'organ', 'ization', '*', 'OUP', '@', '.']
# [0, 713, 7325, 31636, 102, 35001, 1116, 33331, 1644, 10431, 35227, 17247, 1938, 11828, 9834, 35227, 40295, 1891, 10988, 10431, 18, 21527, 2857, 6025, 100, 7325, 31699, 281, 102, 241, 7767, 1990, 30164, 463, 44951, 154, 261, 102, 397, 47811, 1990, 1039, 3226, 17247, 1938, 3226, 44548, 1039, 4, 2]
# 41
# 9
# {'input_ids': [0, 713, 7325, 31636, 102, 35001, 1116, 33331, 1644, 10431, 35227, 17247, 1938, 11828, 9834, 35227, 40295, 1891, 10988, 10431, 18, 21527, 2857, 6025, 100, 7325, 31699, 281, 102, 241, 7767, 1990, 30164, 463, 44951, 154, 261, 102, 397, 47811, 1990, 1039, 3226, 17247, 1938, 3226, 44548, 1039, 4, 2], 'labels': 0, 'ss': 41, 'os': 9}

# %% [markdown]
# ### Potential Issues
#
# * I've been reading through the code, reviewing the associated paper: "https://arxiv.org/abs/2102.01373" and I'm not entirely sure if the offset introduced (simply adding one) is sufficient, even for their implementation. My thinking is that by simply adding one, how exactly are they accounting for the additional '*', '$' and '@', also, their implementation will break down organisation into 'organ' and 'ization' (shouldn't they offset by 2 in that instance, for example?) tags that they're introducing into the representation?
# * We need to be careful of spending too much time on one approach, but I could probably spend a couple of weeks getting to know this code inside out and re-writing it into something a lot more managable and extendable. As it is, whilst it's not the hardest implementation to get your head around, it's not exactly been written with maintainability in mind :| (don't mean to sound too critical!); it would just be nice to have a little more time.
# * So, now I'm really a bit unsure about calculating the offsets for subject start and object start (ss, os).
# * unless, they're just skipping the CLS token, as they've essentially produced their own tokens...? But, I'm not 100% sure that makes sense; I'm going to have to go back to review the original BERT paper again...

# %%
# TODO: tests for verifying the offset & general tests to be implemented in ./tests directory, similar to what was performed above, but using a test suite.

# %% [markdown]
# ## TODO:
#
# * Write tests to verify the logic changes in prepo.py are resulting in the desired output.
# * OPTIONAL: modify the existing codebase to make it a little more maintainable.
# * Verify that the offsets being produced for the subject_start & object_start are appropriate for each of the proposed methods (1) -> (7,8,9).
# * Consider reducing the dataset size/precision/parameters (to speed up the training loop) in order to more quickly verify that the intended effects are occuring.
# * Measure performance agaisnt SpanBERT (currently, we're running BERT & RoBERTa).
# * Obtain results for a couple of other experiments, I'm thinking:
#   * typed_entity_marker VS typed_entity_marker_pos_set, and:
#   * typed_entity_marker_punct VS typed_entity_marker_deprel_set_punct
# * I think that will be more than enough, esp. compared agaisnt three datasets, using and three PLMs for downstream RE.
# * In summary:
#   * 3 datasets (TACRED, TACREV & ReTACRED)
#   * 3 models (BERT_{large}, RoBERTa_{large}, SpanBERT)
#   * 6 methods
# * Recording the results & writing up the paper (at least for RE method #1).
