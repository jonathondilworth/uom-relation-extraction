# %% [markdown]
# # C-GCN Hyperparameter Tuning

# %% [markdown]
# ## Introduction
#
# The goal of this notebook is to showcase how to train the modified C-GCN model.
#
# The notebook is structured as follows:
# 1. Imports and function definitions
# 2. Define hyperparameter grid and other static training parameters
# 3. Execute grid search

# %% [markdown]
# ## 1. Imports and Function Definitions

# %%
import itertools

# %%
# CD into the parent folder for convinience

# %cd ../../src_ra_cgcn
# %pwd
# Out:
# g:\Other computers\My laptop\Laptop Files\University of Manchester\Text Mining\Coursework\COMP61332-re\src_ra_cgcn
# 'g:\\Other computers\\My laptop\\Laptop Files\\University of Manchester\\Text Mining\\Coursework\\COMP61332-re\\src_ra_cgcn'

# %%
def run_grid_search(grid, start_id=100, epochs=100, cgcn=False):
    # build default model parameter string
    default_args = f"--seed 0 --lr 0.3 --num_epoch {epochs} --mlp_layers 2 --pooling_l2 0.003 --hidden_dim 200 --optim sgd --batch_size 50 --attention True "
    if not cgcn:
        default_args += "--no-rnn "

    for i, (prune_k, pooling, posit_emb, pool_bf_attn, sent_emb, num_heads, attn_dropout) in enumerate(itertools.product(*grid)):
        # adjust model ID
        id = start_id + i
        # define new args
        new_cgcn_args = f"--id {id} --prune_k {prune_k} --pooling {pooling} "
        new_attn_args = f"--positional_emb {posit_emb} --pool_before_attention {pool_bf_attn} --use_sentence_emb {sent_emb} --num_heads {num_heads} --attention_dropout {attn_dropout} "
        # combined args
        args = default_args + new_cgcn_args + new_attn_args
        
        print(args)
        # run the bash command
        # %run train.py $args

# %% [markdown]
# ## 2. Define hyperparameter grid and other static training parameters

# %%
# ------------ define grid search parameters ------------
# grid
arg_prune_k = [1, -1]
arg_pooling = ["max"]
arg_posit_emb = ['rot']
arg_pool_bf_attn = [True, False]
arg_sent_emb = [True, False]
arg_num_heads = [1, 10]
arg_attn_dropout = [0, 0.15]

# create grid
grid = [arg_prune_k, arg_pooling, arg_posit_emb, arg_pool_bf_attn, arg_sent_emb, arg_num_heads, arg_attn_dropout]

# print size of grid
print("Grid size:", len(list(itertools.product(*grid))))
# Out:
# Grid size: 32

# %%
# --------------- set the parameters here ---------------
# set start id to not overwrite the previous runs
start_id = 100
# set epoch
epochs = 100
# set whether we run cgcn or not
cgcn = False

# %% [markdown]
# ## 3. Execute grid search

# %%
# ------------------ execute grid search -----------------
run_grid_search(grid=grid, start_id=start_id, epochs=epochs, cgcn=cgcn)
# Out:
# --seed 0 --lr 0.3 --num_epoch 1 --mlp_layers 2 --pooling_l2 0.003 --hidden_dim 200 --optim sgd --batch_size 50 --attention True --no-rnn --id 100 --prune_k 1 --pooling max --positional_emb rot --pool_before_attention True --use_sentence_emb True --num_heads 1 --attention_dropout 0
# Vocab size 50115 loaded from file
# Loading data from ../data/retacred with batch size 50...
# 1170 batches created for ../data/retacred/train.json
# 392 batches created for ../data/retacred/dev.json
# 269 batches created for ../data/retacred/test.json
# Config saved to file ./saved_models/100/config.json
# Overwriting old vocab file at ./saved_models/100/vocab.pkl
#
# Running with the following configs:
# 	data_dir : ../data/retacred
# 	vocab_dir : dataset/vocab
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 200
# 	num_layers : 2
# 	input_dropout : 0.5
# 	gcn_dropout : 0.5
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	prune_k : 1
# 	conv_l2 : 0
# 	pooling : max
# 	pooling_l2 : 0.003
# 	mlp_layers : 2
# 	no_adj : False
# 	rnn : False
# 	rnn_hidden : 200
# 	rnn_layers : 1
# 	rnn_dropout : 0.5
# 	lr : 0.3
# 	lr_decay : 0.9
# 	decay_epoch : 5
# 	optim : sgd
# 	num_epoch : 1
# 	batch_size : 50
# 	max_grad_norm : 5.0
# 	log_step : 20
# 	log : logs.txt
# 	save_epoch : 100
# 	save_dir : ./saved_models
# 	id : 100
# 	info :
# 	seed : 0
# 	cuda : True
# 	cpu : False
# 	load : False
# 	model_file : None
# 	attention : True
# 	pool_before_attention : True
# 	positional_emb : rot
# 	use_sentence_emb : True
# 	num_heads : 1
# 	attention_dropout : 0.0
# 	num_class : 40
# 	vocab_size : 50115
# 	model_save_dir : ./saved_models/100
#
#
# Finetune all embeddings.
# 2025-03-05 22:10:39.498786: step 20/1170 (epoch 1/1), loss = 1.871919 (0.023 sec/batch), lr: 0.300000
# 2025-03-05 22:10:40.124953: step 40/1170 (epoch 1/1), loss = 2.086224 (0.021 sec/batch), lr: 0.300000
# 2025-03-05 22:10:40.745407: step 60/1170 (epoch 1/1), loss = 1.366304 (0.022 sec/batch), lr: 0.300000
# 2025-03-05 22:10:41.367017: step 80/1170 (epoch 1/1), loss = 1.234813 (0.020 sec/batch), lr: 0.300000
# 2025-03-05 22:10:41.988348: step 100/1170 (epoch 1/1), loss = 1.755890 (0.022 sec/batch), lr: 0.300000
# 2025-03-05 22:10
(0.021 sec/batch), lr: 0.300000
# 2025-03-05 22:11:07.646654: step 900/1170 (epoch 1/1), loss = 0.919521 (0.024 sec/batch), lr: 0.300000
# 2025-03-05 22:11:08.275732: step 920/1170 (epoch 1/1), loss = 1.056279 (0.025 sec/batch), lr: 0.300000
# 2025-03-05 22:11:08.894365: step 940/1170 (epoch 1/1), loss = 1.053083 (0.020 sec/batch), lr: 0.300000
# 2025-03-05 22:11:09.508272: step 960/1170 (epoch 1/1), loss = 0.561671 (0.020 sec/batch), lr: 0.300000
# 2025-03-05 22:11:10.120947: step 980/1170 (epoch 1/1), loss = 0.746779 (0.020 sec/batch), lr: 0.300000
# 2025-03-05 22:11:10.728300: step 1000/1170 (epoch 1/1), loss = 0.988735 (0.020 sec/batch), lr: 0.300000
# 2025-03-05 22:11:11.330303: step 1020/1170 (epoch 1/1), loss = 0.850358 (0.021 sec/batch), lr: 0.300000
# 2025-03-05 22:11:11.939825: step 1040/1170 (epoch 1/1), loss = 0.667686 (0.019 sec/batch), lr: 0.300000
# 2025-03-05 22:11:12.547125: step 1060/1170 (epoch 1/1), loss = 0.654109 (0.021 sec/batch), lr: 0.300000
# 2025-03-05 22:11:13.143211: step 1080/1170 (epoch 1/1), loss = 0.751583 (0.020 sec/batch), lr: 0.300000
# 2025-03-05 22:11:13.748626: step 1100/1170 (epoch 1/1), loss = 1.022129 (0.020 sec/batch), lr: 0.300000
# 2025-03-05 22:11:14.347045: step 1120/1170 (epoch 1/1), loss = 0.641564 (0.021 sec/batch), lr: 0.300000
# 2025-03-05 22:11:14.937474: step 1140/1170 (epoch 1/1), loss = 0.742839 (0.019 sec/batch), lr: 0.300000
# 2025-03-05 22:11:15.546303: step 1160/1170 (epoch 1/1), loss = 0.806606 (0.020 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Precision (micro): 48.804%
#    Recall (micro): 48.453%
#        F1 (micro): 48.628%
# epoch 1: train_loss = 1309.732956, dev_loss = 1.056556, dev_f1 = 0.4863
# Evaluating on test set...
# Precision (micro): 52.038%
#    Recall (micro): 53.116%
#        F1 (micro): 52.572%
# [Warning: Saving failed... continuing anyway.]
# New best model saved
# Best Dev Metrics | F1: 0.48627828598940775 | Precision: 0.48804058951437546 | Recall: 0.484528663948189
# Test Metrics at Best Dev | F1: 0.5257162884430037 | Precision: 0.5203816131830009 | Recall: 0.5311614730878187
# model saved to ./saved_models/100/checkpoint_epoch_1.pt
# new best model saved.
#
# Training ended with 1 epochs.
# --seed 0 --lr 0.3 --num_epoch 1 --mlp_layers 2 --pooling_l2 0.003 --hidden_dim 200 --optim sgd --batch_size 50 --attention True --no-rnn --id 101 --prune_k 1 --pooling max --positional_emb rot --pool_before_attention True --use_sentence_emb True --num_heads 1 --attention_dropout 0.15
# Vocab size 50115 loaded from file
# Loading data from ../data/retacred with batch size 50...
# 1170 batches created for ../data/retacred/train.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File G:\Other computers\My laptop\Laptop Files\University of Manchester\Text Mining\Coursework\COMP61332-re\src_ra_cgcn\train.py:127
#     125 print("Loading data from {} with batch size {}...".format(opt['data_dir'], opt['batch_size']))
#     126 train_batch = DataLoader(opt['data_dir'] + '/train.json', opt['batch_size'], opt, vocab, evaluation=False)
# --> 127 dev_batch = DataLoader(opt['data_dir'] + '/dev.json', opt['batch_size'], opt, vocab, evaluation=True)
#     128 test_batch = DataLoader(opt['data_dir'] + '/test.json', opt['batch_size'], opt, vocab, evaluation=True)
#     130 model_id = opt['id'] if len(opt['id']) > 1 else '0' + opt['id']
#
# File G:\Other computers\My laptop\Laptop Files\University of Manchester\Text Mining\Coursework\COMP61332-re\src_ra_cgcn\data\loader.py:24, in DataLoader.__init__(self, filename, batch_size, opt, vocab, evaluation)
#      21 self.label2id = constant.LABEL_TO_ID
#      23 with open(filename) as infile:
# ---> 24     data = json.load(infile)
#      25 self.raw_data = data
#      26 data = self.preprocess(data, vocab, opt)
#
# File c:\Users\Alex\anaconda3\envs\tm\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File c:\Users\Alex\anaconda3\envs\tm\lib\json\__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352     del kw['encoding']
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#     359     cls = JSONDecoder
#
# File c:\Users\Alex\anaconda3\envs\tm\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\Alex\anaconda3\envs\tm\lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:
# --seed 0 --lr 0.3 --num_epoch 1 --mlp_layers 2 --pooling_l2 0.003 --hidden_dim 200 --optim sgd --batch_size 50 --attention True --no-rnn --id 102 --prune_k 1 --pooling max --positional_emb rot --pool_before_attention True --use_sentence_emb True --num_heads 10 --attention_dropout 0
# Vocab size 50115 loaded from file
# Loading data from ../data/retacred with batch size 50...
# 1170 batches created for ../data/retacred/train.json
# 392 batches created for ../data/retacred/dev.json
# 269 batches created for ../data/retacred/test.json
# Directory ./saved_models/102 do not exist; creating...
# Config saved to file ./saved_models/102/config.json
#
# Running with the following configs:
# 	data_dir : ../data/retacred
# 	vocab_dir : dataset/vocab
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 200
# 	num_layers : 2
# 	input_dropout : 0.5
# 	gcn_dropout : 0.5
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	prune_k : 1
# 	conv_l2 : 0
# 	pooling : max
# 	pooling_l2 : 0.003
# 	mlp_layers : 2
# 	no_adj : False
# 	rnn : False
# 	rnn_hidden : 200
# 	rnn_layers : 1
# 	rnn_dropout : 0.5
# 	lr : 0.3
# 	lr_decay : 0.9
# 	decay_epoch : 5
# 	optim : sgd
# 	num_epoch : 1
# 	batch_size : 50
# 	max_grad_norm : 5.0
# 	log_step : 20
# 	log : logs.txt
# 	save_epoch : 100
# 	save_dir : ./saved_models
# 	id : 102
# 	info :
# 	seed : 0
# 	cuda : True
# 	cpu : False
# 	load : False
# 	model_file : None
# 	attention : True
# 	pool_before_attention : True
# 	positional_emb : rot
# 	use_sentence_emb : True
# 	num_heads : 10
# 	attention_dropout : 0.0
# 	num_class : 40
# 	vocab_size : 50115
# 	model_save_dir : ./saved_models/102
#
#
# Finetune all embeddings.
