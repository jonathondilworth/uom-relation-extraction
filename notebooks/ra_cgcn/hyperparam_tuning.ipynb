# %%
# CD into the parent folder for convinience

# %cd ../../src_ra_cgcn
# %pwd
# Out:
# /Users/rojsaktumanis/Desktop/Studies/Manchester modules/Text mining/RE CW/CW/uom-relation-extraction/src_ra_cgcn
# '/Users/rojsaktumanis/Desktop/Studies/Manchester modules/Text mining/RE CW/CW/uom-relation-extraction/src_ra_cgcn'

# %%
import itertools

# %%
# ------------ define grid search parameters ------------
# grid
arg_prune_k = [1, -1]
arg_pooling = ["max"]
arg_posit_emb = ['rot']
arg_pool_bf_attn = [True, False]
arg_sent_emb = [True, False]
arg_num_heads = [1, 10]
arg_attn_dropout = [0, 0.15]

# %%
# --------------- set the parameters here ---------------
# set start id to not overwrite the previous runs
start_id = 100
# set epoch
epochs = 100
# set whether we run cgcn or not
cgcn = False

# %%
# ------------------ execute grid search -----------------
# build default model parameter string
default_args = f"--seed 0 --lr 0.3 --num_epoch {epochs} --mlp_layers 2 --pooling_l2 0.003 --hidden_dim 200 --optim sgd --batch_size 50 --attention True "
if not cgcn:
    default_args += "--no-rnn "

for i, (prune_k, pooling, posit_emb, pool_bf_attn, sent_emb, num_heads, attn_dropout) in enumerate(
    itertools.product(arg_prune_k, arg_pooling, arg_posit_emb, arg_pool_bf_attn, arg_sent_emb, arg_num_heads, arg_attn_dropout)):
    # adjust model ID
    id = start_id + i
    # define new args
    new_cgcn_args = f"--id {id} --prune_k {prune_k} --pooling {pooling} "
    new_attn_args = f"--positional_emb {posit_emb} --pool_before_attention {pool_bf_attn} --use_sentence_emb {sent_emb} --num_heads {num_heads} --attention_dropout {attn_dropout} "
    # combined args
    args = default_args + new_cgcn_args + new_attn_args
    
    print(args)
    # run the bash command
    # %run train.py $args
    break
# Out:
# --seed 0 --lr 0.3 --num_epoch 1 --mlp_layers 2 --pooling_l2 0.003 --hidden_dim 200 --optim sgd --batch_size 50 --attention True --no-rnn --id 100 --prune_k 1 --pooling max --positional_emb rot --pool_before_attention True --use_sentence_emb True --num_heads 1 --attention_dropout 0
# Vocab size 50115 loaded from file
# Loading data from ../data/retacred with batch size 50...
# 1170 batches created for ../data/retacred/train.json
# 392 batches created for ../data/retacred/dev.json
# 269 batches created for ../data/retacred/test.json
# Config saved to file ./saved_models/100/config.json
# Overwriting old vocab file at ./saved_models/100/vocab.pkl
#
# Running with the following configs:
# 	data_dir : ../data/retacred
# 	vocab_dir : dataset/vocab
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 200
# 	num_layers : 2
# 	input_dropout : 0.5
# 	gcn_dropout : 0.5
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	prune_k : 1
# 	conv_l2 : 0
# 	pooling : max
# 	pooling_l2 : 0.003
# 	mlp_layers : 2
# 	no_adj : False
# 	rnn : False
# 	rnn_hidden : 200
# 	rnn_layers : 1
# 	rnn_dropout : 0.5
# 	lr : 0.3
# 	lr_decay : 0.9
# 	decay_epoch : 5
# 	optim : sgd
# 	num_epoch : 1
# 	batch_size : 50
# 	max_grad_norm : 5.0
# 	log_step : 20
# 	log : logs.txt
# 	save_epoch : 100
# 	save_dir : ./saved_models
# 	id : 100
# 	info :
# 	seed : 0
# 	cuda : False
# 	cpu : False
# 	load : False
# 	model_file : None
# 	attention : True
# 	pool_before_attention : True
# 	positional_emb : rot
# 	use_sentence_emb : True
# 	num_heads : 1
# 	attention_dropout : 0.0
# 	num_class : 40
# 	vocab_size : 50115
# 	model_save_dir : ./saved_models/100
#
#
# Finetune all embeddings.
# 2025-03-05 15:01:37.485180: step 20/1170 (epoch 1/1), loss = 2.115582 (0.074 sec/batch), lr: 0.300000
# 2025-03-05 15:01:38.796136: step 40/1170 (epoch 1/1), loss = 2.095798 (0.061 sec/batch), lr: 0.300000
# 2025-03-05 15:01:40.205240: step 60/1170 (epoch 1/1), loss = 1.372751 (0.064 sec/batch), lr: 0.300000
# 2025-03-05 15:01:41.539976: step 80/1170 (epoch 1/1), loss = 1.248950 (0.064 sec/batch), lr: 0.300000
# 2025-03-05 15:01:42.898504: step 100/1170 (epoch 1/1), loss = 1.793796 (0.071 sec/batch), lr: 0.300000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Desktop/Studies/Manchester modules/Text mining/RE CW/CW/uom-relation-extraction/src_ra_cgcn/train.py:172
#     170 start_time = time.time()
#     171 global_step += 1
# --> 172 loss = trainer.update(batch)
#     173 train_loss += loss
#     174 if global_step % opt['log_step'] == 0:
#
# File ~/Desktop/Studies/Manchester modules/Text mining/RE CW/CW/uom-relation-extraction/src_ra_cgcn/model/trainer.py:80, in GCNTrainer.update(self, batch)
#      78 self.model.train()
#      79 self.optimizer.zero_grad()
# ---> 80 logits, pooling_output = self.model(inputs)
#      81 loss = self.criterion(logits, labels)
#      82 # l2 decay on all conv layers
#
# File ~/miniconda3/envs/tm/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/tm/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Desktop/Studies/Manchester modules/Text mining/RE CW/CW/uom-relation-extraction/src_ra_cgcn/model/gcn.py:32, in GCNClassifier.forward(self, inputs)
#      31 def forward(self, inputs):
# ---> 32     outputs, pooling_output = self.gcn_model(inputs)
#      33     logits = self.classifier(outputs)
#      34     return logits, pooling_output
#
# File ~/miniconda3/envs/tm/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/tm/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Desktop/Studies/Manchester modules/Text mining/RE CW/CW/uom-relation-extraction/src_ra_cgcn/model/gcn.py:127, in GCNRelationModel.forward(self, inputs)
#     124     return Variable(adj.cuda()) if self.opt['cuda'] else Variable(adj)
#     126 adj = inputs_to_tree_reps(head.data, words.data, l, self.opt['prune_k'], subj_pos.data, obj_pos.data)
# --> 127 h, pool_mask = self.gcn(adj, inputs)
#     129 # masks
#     130 subj_mask, obj_mask = subj_pos.eq(0).eq(0).unsqueeze(2), obj_pos.eq(0).eq(0).unsqueeze(2) # invert mask
#
# File ~/miniconda3/envs/tm/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/tm/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Desktop/Studies/Manchester modules/Text mining/RE CW/CW/uom-relation-extraction/src_ra_cgcn/model/gcn.py:264, in GCN.forward(self, adj, inputs)
#     262     embs += [self.ner_emb(ner)]
#     263 embs = torch.cat(embs, dim=2)
# --> 264 embs = self.in_drop(embs)
#     266 # rnn layer
#     267 if self.opt.get('rnn', False):
#
# File ~/miniconda3/envs/tm/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/tm/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/miniconda3/envs/tm/lib/python3.8/site-packages/torch/nn/modules/dropout.py:59, in Dropout.forward(self, input)
#      58 def forward(self, input: Tensor) -> Tensor:
# ---> 59     return F.dropout(input, self.p, self.training, self.inplace)
#
# File ~/miniconda3/envs/tm/lib/python3.8/site-packages/torch/nn/functional.py:1295, in dropout(input, p, training, inplace)
#    1293 if p < 0.0 or p > 1.0:
#    1294     raise ValueError(f"dropout probability has to be between 0 and 1, but got {p}")
# -> 1295 return _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#
# KeyboardInterrupt:
