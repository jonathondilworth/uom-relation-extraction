# %% [markdown]
# # C-GCN Hyperparameter Tuning

# %% [markdown]
# ## Introduction
#
# The goal of this notebook is to showcase how to train the modified C-GCN model.
#
# The notebook is structured as follows:
# 1. Setup (Imports and function definitions)
# 2. Define hyperparameter grid and other static training parameters
# 3. Execute grid search

# %% [markdown]
# ## 1. Setup (Imports and Function Definitions)

# %%
import itertools

# %%
# CD into the parent folder for convinience

# %cd ../../src_ra_cgcn
# %pwd
# Out:
# /Users/rojsaktumanis/Desktop/Studies/Manchester modules/Text mining/RE CW/CW/uom-relation-extraction/src_ra_cgcn
# '/Users/rojsaktumanis/Desktop/Studies/Manchester modules/Text mining/RE CW/CW/uom-relation-extraction/src_ra_cgcn'

# %%
def run_grid_search(grid, start_id=100, epochs=100, cgcn=False):
    # build default model parameter string
    default_args = f"--seed 0 --lr 0.3 --num_epoch {epochs} --mlp_layers 2 --pooling_l2 0.003 --hidden_dim 200 --optim sgd --batch_size 50 --attention True "
    if not cgcn:
        default_args += "--no-rnn "

    for i, (prune_k, pooling, posit_emb, pool_bf_attn, sent_emb, num_heads, attn_dropout) in enumerate(itertools.product(*grid)):
        # adjust model ID
        id = start_id + i
        # define new args
        new_cgcn_args = f"--id {id} --prune_k {prune_k} --pooling {pooling} "
        new_attn_args = f"--positional_emb {posit_emb} --pool_before_attention {pool_bf_attn} --use_sentence_emb {sent_emb} --num_heads {num_heads} --attention_dropout {attn_dropout} "
        # combined args
        args = default_args + new_cgcn_args + new_attn_args
        
        print(args)
        # run the bash command
        # %run train.py $args

# %%
def train_attention_model(model_id, epochs, cgcn=False, **model_params):
    # build default model parameter string
    default_args = f"--seed 0 --lr 0.3 --num_epoch {epochs} --mlp_layers 2 --pooling_l2 0.003 --hidden_dim 200 --optim sgd --batch_size 50 --attention True "
    if not cgcn:
        default_args += "--no-rnn "

    # adjust model ID
    id = model_id
    # define new args
    new_args = f"--id {id} "
    new_args += " ".join([f"--{k} {v}" for k, v in model_params.items()])
    # combined args
    args = default_args + new_args

    print(args)
    # run the bash command
    # %run train.py $args
    
def train_og_model(model_id, epochs, cgcn=False):
    # build default model parameter string
    default_args = f"--seed 0 --lr 0.3 --num_epoch {epochs} --mlp_layers 2 --pooling_l2 0.003 --hidden_dim 200 --optim sgd --batch_size 50 --attention False "
    if not cgcn:
        default_args += "--no-rnn "

    # adjust model ID
    id = model_id
    # define new args
    new_args = f"--id {id} --positional_emb none --pool_before_attention True --use_sentence_emb True --pooling max --prune_k 1 "
    # combined args
    args = default_args + new_args

    print(args)
    # run the bash command
    # %run train.py $args

# %% [markdown]
# ## 2. Define hyperparameter grid and other static training parameters

# %%
# ------------ define grid search parameters ------------
# # grid
# arg_prune_k = [1, -1]
# arg_pooling = ["max"]
# arg_posit_emb = ['rot']
# arg_pool_bf_attn = [True, False]
# arg_sent_emb = [True, False]
# arg_num_heads = [1, 10]
# arg_attn_dropout = [0, 0.15]

# new grid
arg_prune_k = [1]
arg_pooling = ["max"]
arg_posit_emb = ['rot']
arg_pool_bf_attn = [True]
arg_sent_emb = [True]
arg_num_heads = [1, 4]
arg_attn_dropout = [0.1, 0.3, 0.5]

# create grid
grid = [arg_prune_k, arg_pooling, arg_posit_emb, arg_pool_bf_attn, arg_sent_emb, arg_num_heads, arg_attn_dropout]


# print size of grid
print("Grid size:", len(list(itertools.product(*grid))))
# Out:
# Grid size: 6

# %%
# --------------- set the parameters here ---------------
# set start id to not overwrite the previous runs
start_id = 300
# set epoch
epochs = 100
# set whether we run cgcn or not
cgcn = False

# %% [markdown]
# ## 3. Execute grid search

# %%
# ------------------ execute grid search -----------------
run_grid_search(grid=grid, start_id=start_id, epochs=epochs, cgcn=cgcn)
# Out:
# 1 max rot True True 1 0.1
# 1 max rot True True 1 0.3
# 1 max rot True True 1 0.5
# 1 max rot True True 4 0.1
# 1 max rot True True 4 0.3
# 1 max rot True True 4 0.5

# %% [markdown]
# ## 4. Train the best model

# %%
train_attention_model(model_id=400, epochs=1, cgcn=False, prune_k = 1, pooling = "max", positional_emb = "rot", 
                      pool_before_attention = True, use_sentence_emb = True, num_heads = 1, attention_dropout = 0.15)
# Out:
# --seed 0 --lr 0.3 --num_epoch 1 --mlp_layers 2 --pooling_l2 0.003 --hidden_dim 200 --optim sgd --batch_size 50 --attention True --no-rnn --id 400 --prune_k 1 --pooling max --positional_emb rot --pool_before_attention True --use_sentence_emb True --num_heads 1 --attention_dropout 0.15
# Vocab size 50115 loaded from file
# Loading data from ../data/retacred with batch size 50...
# 1170 batches created for ../data/retacred/train.json
# 392 batches created for ../data/retacred/dev.json
# 269 batches created for ../data/retacred/test.json
# Directory ./saved_models/400 do not exist; creating...
# Config saved to file ./saved_models/400/config.json
#
# Running with the following configs:
# 	data_dir : ../data/retacred
# 	vocab_dir : dataset/vocab
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 200
# 	num_layers : 2
# 	input_dropout : 0.5
# 	gcn_dropout : 0.5
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	prune_k : 1
# 	conv_l2 : 0
# 	pooling : max
# 	pooling_l2 : 0.003
# 	mlp_layers : 2
# 	no_adj : False
# 	rnn : False
# 	rnn_hidden : 200
# 	rnn_layers : 1
# 	rnn_dropout : 0.5
# 	lr : 0.3
# 	lr_decay : 0.9
# 	decay_epoch : 5
# 	optim : sgd
# 	num_epoch : 1
# 	batch_size : 50
# 	max_grad_norm : 5.0
# 	log_step : 20
# 	log : logs.txt
# 	save_epoch : 100
# 	save_dir : ./saved_models
# 	id : 400
# 	info :
# 	seed : 0
# 	cuda : False
# 	cpu : False
# 	load : False
# 	model_file : None
# 	attention : True
# 	pool_before_attention : True
# 	positional_emb : rot
# 	use_sentence_emb : True
# 	num_heads : 1
# 	attention_dropout : 0.15
# 	num_class : 40
# 	vocab_size : 50115
# 	model_save_dir : ./saved_models/400
#
#
# Finetune all embeddings.
# 2025-03-06 17:26:13.348261: step 20/1170 (epoch 1/1), loss = 2.082875 (0.061 sec/batch), lr: 0.300000
# 2025-03-06 17:26:14.728132: step 40/1170 (epoch 1/1), loss = 2.087862 (0.062 sec/batch), lr: 0.300000
# 2025-03-06 17:26:16.032527: step 60/1170 (epoch 1/1), loss = 1.397133 (0.072 sec/batch), lr: 0.300000
# 2025-03-06 17:26:17.612229: step 80/1170 (epoch 1/1), loss = 1.247579 (0.064 sec/batch), lr: 0.300000
# 2025-03-06 17:26:19.138747: step 100/1170 (epoch 1/1), loss = 1.766781 (0.079 sec/batch), lr: 0.300000
# 2025-03-06 17:26:20.494323: step 120/1170 (epoch 1/1), loss = 1.381080 (0.064 sec/batch), lr: 0.300000
# 2025-03-06 17:26:21.898520: step 140/1170 (epoch 1/1), loss = 1.511228 (0.067 sec/batch), lr: 0.300000
# 2025-03-06 17:26:23.236013: step 160/1170 (epoch 1/1), loss = 1.131823 (0.065 sec/batch), lr: 0.300000
# 2025-03-06 17:26:24.562801: step 180/1170 (epoch 1/1), loss = 1.286343 (0.058 sec/batch), lr: 0.300000
# 2025-03-06 17:26:25.902953: step 200/1170 (epoch 1/1), loss = 0.882746 (0.061 sec/batch), lr: 0.300000
# 2025-03-06 17:26:27.311509: step 220/1170 (epoch 1/1), loss = 1.259077 (0.064 sec/batch), lr: 0.300000
# 2025-03-06 17:26:28.820420: step 240/1170 (epoch 1/1), loss = 1.645320 (0.066 sec/batch), lr: 0.300000
# 2025-03-06 17:26:30.163043: step 260/1170 (epoch 1/1), loss = 1.735456 (0.072 sec/batch), lr: 0.300000
# 2025-03-06 17:26:31.482247: step 280/1170 (epoch 1/1), loss = 1.306909 (0.061 sec/batch), lr: 0.300000
# 2025-03-06 17:26:32.938230: step 300/1170 (epoch 1/1), loss = 0.850766 (0.057 sec/batch), lr: 0.300000
# 2025-03-06 17:26:34.642828: step 320/1170 (epoch 1/1), loss = 1.180731 (0.157 sec/batch), lr: 0.300000
# 2025-03-06 17:26:36.139588: step 340/1170 (epoch 1/1), loss = 1.245830 (0.080 sec/batch), lr: 0.300000
# 2025-03-06 17:26:37.724603: step 360/1170 (epoch 1/1), loss = 1.984895 (0.073 sec/batch), lr: 0.300000
# 2025-03-06 17:26:39.284354: step 380/1170 (epoch 1/1), loss = 1.320757 (0.118 sec/batch), lr: 0.300000
# 2025-03-06 17:26:40.827253: step 400/1170 (epoch 1/1), loss = 1.143217 (0.068 sec/batch), lr: 0.300000
# 2025-03-06 17:27:22.362394: step 1020/1170 (epoch 1/1), loss = 0.977356 (0.069 sec/batch), lr: 0.300000
# 2025-03-06 17:27:23.694620: step 1040/1170 (epoch 1/1), loss = 0.677860 (0.060 sec/batch), lr: 0.300000
# 2025-03-06 17:27:24.991177: step 1060/1170 (epoch 1/1), loss = 0.622949 (0.063 sec/batch), lr: 0.300000
# 2025-03-06 17:27:26.286390: step 1080/1170 (epoch 1/1), loss = 0.705794 (0.064 sec/batch), lr: 0.300000
# 2025-03-06 17:27:27.640558: step 1100/1170 (epoch 1/1), loss = 1.006809 (0.057 sec/batch), lr: 0.300000
# 2025-03-06 17:27:28.889873: step 1120/1170 (epoch 1/1), loss = 0.558011 (0.066 sec/batch), lr: 0.300000
# 2025-03-06 17:27:30.154001: step 1140/1170 (epoch 1/1), loss = 0.681336 (0.057 sec/batch), lr: 0.300000
# 2025-03-06 17:27:31.488798: step 1160/1170 (epoch 1/1), loss = 0.885004 (0.060 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Precision (micro): 45.109%
#    Recall (micro): 42.252%
#        F1 (micro): 43.634%
# epoch 1: train_loss = 1324.368422, dev_loss = 1.171619, dev_f1 = 0.4363
# Evaluating on test set...
# Precision (micro): 50.128%
#    Recall (micro): 48.442%
#        F1 (micro): 49.271%
# [Warning: Saving failed... continuing anyway.]
# New best model saved
# Best Dev Metrics | F1: 0.4363388654941789 | Precision: 0.45108834827144684 | Recall: 0.42252338690333413
# Test Metrics at Best Dev | F1: 0.4927066450567261 | Precision: 0.501282521069989 | Recall: 0.48441926345609065
# model saved to ./saved_models/400/checkpoint_epoch_1.pt
# new best model saved.
#
# Training ended with 1 epochs.

# %%
# train a baseline GCN model
train_og_model(model_id=500, epochs=1, cgcn=False)
# Out:
# --seed 0 --lr 0.3 --num_epoch 1 --mlp_layers 2 --pooling_l2 0.003 --hidden_dim 200 --optim sgd --batch_size 50 --attention False --no-rnn --id 500 --positional_emb none --pool_before_attention True --use_sentence_emb True --pooling max --prune_k 1
# Vocab size 50115 loaded from file
# Loading data from ../data/retacred with batch size 50...
# 1170 batches created for ../data/retacred/train.json
# 392 batches created for ../data/retacred/dev.json
# 269 batches created for ../data/retacred/test.json
# Directory ./saved_models/500 do not exist; creating...
# Config saved to file ./saved_models/500/config.json
#
# Running with the following configs:
# 	data_dir : ../data/retacred
# 	vocab_dir : dataset/vocab
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 200
# 	num_layers : 2
# 	input_dropout : 0.5
# 	gcn_dropout : 0.5
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	prune_k : 1
# 	conv_l2 : 0
# 	pooling : max
# 	pooling_l2 : 0.003
# 	mlp_layers : 2
# 	no_adj : False
# 	rnn : False
# 	rnn_hidden : 200
# 	rnn_layers : 1
# 	rnn_dropout : 0.5
# 	lr : 0.3
# 	lr_decay : 0.9
# 	decay_epoch : 5
# 	optim : sgd
# 	num_epoch : 1
# 	batch_size : 50
# 	max_grad_norm : 5.0
# 	log_step : 20
# 	log : logs.txt
# 	save_epoch : 100
# 	save_dir : ./saved_models
# 	id : 500
# 	info :
# 	seed : 0
# 	cuda : False
# 	cpu : False
# 	load : False
# 	model_file : None
# 	attention : False
# 	pool_before_attention : True
# 	positional_emb : none
# 	use_sentence_emb : True
# 	num_heads : 4
# 	attention_dropout : 0.01
# 	num_class : 40
# 	vocab_size : 50115
# 	model_save_dir : ./saved_models/500
#
#
# Finetune all embeddings.
# 2025-03-06 17:27:52.910952: step 20/1170 (epoch 1/1), loss = 2.079306 (0.038 sec/batch), lr: 0.300000
# 2025-03-06 17
(0.037 sec/batch), lr: 0.300000
# 2025-03-06 17:28:23.671421: step 720/1170 (epoch 1/1), loss = 0.980113 (0.032 sec/batch), lr: 0.300000
# 2025-03-06 17:28:24.483924: step 740/1170 (epoch 1/1), loss = 0.624378 (0.039 sec/batch), lr: 0.300000
# 2025-03-06 17:28:25.301004: step 760/1170 (epoch 1/1), loss = 1.100530 (0.042 sec/batch), lr: 0.300000
# 2025-03-06 17:28:26.113283: step 780/1170 (epoch 1/1), loss = 1.222463 (0.036 sec/batch), lr: 0.300000
# 2025-03-06 17:28:26.912911: step 800/1170 (epoch 1/1), loss = 0.872708 (0.042 sec/batch), lr: 0.300000
# 2025-03-06 17:28:27.692146: step 820/1170 (epoch 1/1), loss = 1.082764 (0.033 sec/batch), lr: 0.300000
# 2025-03-06 17:28:28.478868: step 840/1170 (epoch 1/1), loss = 1.136655 (0.039 sec/batch), lr: 0.300000
# 2025-03-06 17:28:29.321997: step 860/1170 (epoch 1/1), loss = 0.712231 (0.037 sec/batch), lr: 0.300000
# 2025-03-06 17:28:30.115078: step 880/1170 (epoch 1/1), loss = 0.842064 (0.033 sec/batch), lr: 0.300000
# 2025-03-06 17:28:30.936897: step 900/1170 (epoch 1/1), loss = 0.956134 (0.038 sec/batch), lr: 0.300000
# 2025-03-06 17:28:31.727146: step 920/1170 (epoch 1/1), loss = 1.051745 (0.042 sec/batch), lr: 0.300000
# 2025-03-06 17:28:32.521738: step 940/1170 (epoch 1/1), loss = 1.051781 (0.038 sec/batch), lr: 0.300000
# 2025-03-06 17:28:33.326632: step 960/1170 (epoch 1/1), loss = 0.564808 (0.036 sec/batch), lr: 0.300000
# 2025-03-06 17:28:34.156757: step 980/1170 (epoch 1/1), loss = 0.750971 (0.038 sec/batch), lr: 0.300000
# 2025-03-06 17:28:34.976325: step 1000/1170 (epoch 1/1), loss = 0.967867 (0.036 sec/batch), lr: 0.300000
# 2025-03-06 17:28:35.788144: step 1020/1170 (epoch 1/1), loss = 0.909214 (0.038 sec/batch), lr: 0.300000
# 2025-03-06 17:28:36.600407: step 1040/1170 (epoch 1/1), loss = 0.686828 (0.033 sec/batch), lr: 0.300000
# 2025-03-06 17:28:37.414558: step 1060/1170 (epoch 1/1), loss = 0.654167 (0.034 sec/batch), lr: 0.300000
# 2025-03-06 17:28:38.263562: step 1080/1170 (epoch 1/1), loss = 0.810336 (0.039 sec/batch), lr: 0.300000
# 2025-03-06 17:28:39.094728: step 1100/1170 (epoch 1/1), loss = 0.962295 (0.037 sec/batch), lr: 0.300000
# 2025-03-06 17:28:39.925302: step 1120/1170 (epoch 1/1), loss = 0.629262 (0.042 sec/batch), lr: 0.300000
# 2025-03-06 17:28:40.730985: step 1140/1170 (epoch 1/1), loss = 0.745584 (0.035 sec/batch), lr: 0.300000
# 2025-03-06 17:28:41.563750: step 1160/1170 (epoch 1/1), loss = 0.846159 (0.036 sec/batch), lr: 0.300000
# Evaluating on dev set...
# Precision (micro): 47.776%
#    Recall (micro): 49.856%
#        F1 (micro): 48.794%
# epoch 1: train_loss = 1321.185403, dev_loss = 1.138488, dev_f1 = 0.4879
# Evaluating on test set...
# Precision (micro): 51.224%
#    Recall (micro): 54.834%
#        F1 (micro): 52.967%
# [Warning: Saving failed... continuing anyway.]
# New best model saved
# Best Dev Metrics | F1: 0.4879394330653207 | Precision: 0.4777611768762211 | Recall: 0.49856080594866875
# Test Metrics at Best Dev | F1: 0.5296733367538907 | Precision: 0.5122394971882236 | Recall: 0.5483356940509915
# model saved to ./saved_models/500/checkpoint_epoch_1.pt
# new best model saved.
#
# Training ended with 1 epochs.
