# %% [markdown]
# #BERT with Enhanced Typed Entity Markers
#
# #Introduction
#
# The notebook is structured as follows:
#   1. Setup
#   2. Training

# %% [markdown]
# #Setup

# %% [markdown]
# ###Colab setup -- clone repo

# %%
# !git clone https://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@github.com/jonathondilworth/uom-relation-extraction.git
# Out:
# Cloning into 'uom-relation-extraction'...
# remote: Enumerating objects: 405, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 405 (delta 9), reused 27 (delta 7), pack-reused 342 (from 1)
# Receiving objects: 100% (405/405), 10.83 MiB | 11.69 MiB/s, done.
# Resolving deltas: 100% (187/187), done.

# %%
# %cd uom-relation-extraction
# Out:
# /content/uom-relation-extraction

# %% [markdown]
# ###Switch to correct branch (delete when everything is on main)

# %%
# !git branch -r
# Out:
#   origin/HEAD -> origin/main
#   origin/am-cgcn-experimentation
#   origin/eo-svm-experiments
#   origin/jd-baseline-changes
#   origin/jd-checkpoint-load-and-eval
#   origin/jd-init
#   origin/jd-re-baseline-src
#   origin/main
#   origin/ra-cgcn

# %%
# !git checkout -b jd-checkpoint-load-and-eval origin/jd-checkpoint-load-and-eval
# Out:
# Branch 'jd-checkpoint-load-and-eval' set up to track remote branch 'jd-checkpoint-load-and-eval' from 'origin'.
# Switched to a new branch 'jd-checkpoint-load-and-eval'

# %% [markdown]
# ###Dataset setup instructions
#
# Before running the training scripts, make sure your dataset files are placed inside the repository with the following structure:
#
# ```
# uom-relation-extraction/
# │── data/
# │   ├── retacred/
# │   │   ├── train.json
# │   │   ├── dev.json
# │   │   ├── test.json
# │   ├── tacred/
# │   │   ├── train.json
# │   │   ├── dev.json
# │   │   ├── test.json
# │   │   ├── dev_rev.json
# │   │   ├── test_rev.json
# ```

# %% [markdown]
# ###Installations & imports

# %%
# !pip install -r "requirements.txt"  > /dev/null 2>&1

# %% [markdown]
# # Training: POS-Tag & Dependency Relation Variations in Entity Markers
#
# We are testing different **POS-tag and dependency relation variations** within entity markers to improve the model’s **syntactic understanding**.
# This builds upon previous entity marker variations (without POS or dependency tags) explored in
# ["An Improved Baseline for Sentence-level Relation Extraction"](https://arxiv.org/abs/1905.08284).
#
# By incorporating **POS and dependency relation information** within entity markers, we are trying to increase model’s ability to capture **syntactic relationships** more effectively. The experiments will compare model performance across different entity marker variations to assess their impact on relation extraction.
#
#
#
# ### Example Sentence
# To illustrate the techniques, consider the sentence:
# **"The King of England lives in Buckingham Palace."**
#
#
#
# ## New Variations
#
# ### 1. **Typed Entity Marker POS Punct**
# – Appends the **first POS tag** using punctuation-based markers.
#    - **Format:**  ```  @ *NER type+first POS tag* subject@ ...# ^NER type + first POS tag^ object# ```
#    - **Example:**  ```  @*PERSON+DT*The King of England@ lives in #^LOCATION+NNP^Buckingham Palace#. ```
#
# ### 2. **Typed Entity Marker DepRel Set Punct**
#  – Incorporates **dependency relation (DepRel) tags** for both subject and object entities using a **set of unique dependeny relations**.
#    - **Format:**   ```  @ *NER type + DepRel Set* subject@ ... #^NER type + DepRel Set^ object# ```
#
#    - **Example:**   ```  @*PERSON+nsubj set case nmod*The King of England@ lives in #^LOCATION+compound obl^Buckingham Palace#. ```

# %%
#pick seed
SEED= 42

# %% [markdown]
# ###1. Typed Entity Marker with POS tag approach
#
# We are demonstrating one model for simplicity -- but if you want to train the other, just change the ```input_format``` to  ```typed_entity_marker_deprel_set_punct```.

# %%
# !python -W ignore src/train_retacred.py \
    --model_name_or_path bert-base-cased \
    --input_format typed_entity_marker_pos \
    --seed $SEED \
    --data_dir ./data/retacred \
    --train_batch_size 64 \
    --test_batch_size 64 \
    --learning_rate 5e-5 \
    --gradient_accumulation_steps 1 \
    --run_name bert-base
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Tracking run with wandb version 0.19.7
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# 2025-03-07 14:43:55.546825: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-07 14:43:55.565641: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741358635.587610    1785 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741358635.594373    1785 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-07 14:43:55.616936: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 100% 58465/58465 [01:17<00:00, 752.61it/s]
# 100% 19584/19584 [00:25<00:00, 782.27it/s]
# 100% 13418/13418 [00:16<00:00, 796.60it/s]
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# Total steps: 4565
# Warmup steps: 456
#  55% 499/913 [00:44<00:36, 11.29it/s]{'dev_f1': 72.22676136006537}
# new best model saved.
# {'test_f1': 73.1348768834987}
# 100% 913/913 [01:31<00:00, 10.00it/s]
#   9% 86/913 [00:07<01:14, 11.03it/s][ Trying to save checkpoint to: ./saved_models/checkpoint-1000.pt ] ...
# model saved to: ./saved_models/checkpoint-1000.pt
# {'dev_f1': 82.94064477252185}
# new best model saved.
# {'test_f1': 83.8009528851244}
#  64% 586/913 [01:03<00:25, 12.63it/s]{'dev_f1': 84.84477374318782}
# new best model saved.
# {'test_f1': 85.8996618843096}
# 100% 913/913 [01:41<00:00,  8.95it/s]
#  19% 172/913 [00:15<01:01, 12.00it/s][ Trying to save checkpoint to: ./saved_models/checkpoint-2000.pt ] ...
# model saved to: ./saved_models/checkpoint-2000.pt
# {'dev_f1': 85.67033487161282}
# new best model saved.
# {'test_f1': 86.36601992658625}
#  27% 250/913 [00:33<00:57, 11.59it/s]
